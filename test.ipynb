# %%
import requests
import os 
from dotenv import load_dotenv
import pandas as pd
from sqlalchemy import create_engine

load_dotenv()

url = ('https://newsapi.org/v2/everything?'
       'q=Apple&'
       'from=2026-05-15&'
       'sortBy=popularity&'
       'apiKey=' + os.getenv('NEWS_API_KEY'))

response = requests.get(url)

response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 37427,
#  'articles': [{'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Louryn Strampe',
#    'title': 'Memorial Day Tech Deals: Sony, Apple, Beats (2026)',
#    'description': 'Lots of our most-recommended headphones, power banks, and other gadgets are on sale for Memorial Day.',
#    'url': 'https://www.wired.com/story/memorial-day-tech-deals-2026-1/',
#    'urlToImage': 'https://media.wired.com/photos/6a06188db84b146a9eec38c1/191:100/w_1280,c_limit/Memorial%20Day%20Deals%20Tech%20top%20art%20052026%20SOURCE%20Amazon.jpg',
#    'publishedAt': '2026-05-22T18:52:47Z',
#    'content': "When you think of Memorial Day sales, you probably think of mattresses and other home goods. And while those items are definitely discounted, now is also a good time to purchase tech. Personally, I'm… [+1064 chars]"},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Luke Larsen',
#    'title': 'MacOS 27 Golden Gate: Top New Features',
#    'description': "Apple has announced the latest version of macOS. It's all about the reintroduction of Siri, which is now accessible from anywhere on the Mac desktop.",
#    'url': 'https://www.wired.com/story/macos-27-golden-gate-top-features/',
#    'urlToImage': 'https://media.wired.com/photos/6a2849c20d6aa02c6a8cdf9e/191:100/w_1280,c_limit/Apple-OS-27-updates-260608.jpg',
#    'publishedAt': '2026-06-09T17:33:21Z',
#    'content': 'One of the most interesting new features is Custom Extensions, which lets you create an extension for Safari in natural language. Lastly, the new version of Safari will work the Passwords app to auto… [+2328 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Julian Chokkattu',
#    'title': 'Apple’s iPhone Camera App Is Getting an AI Upgrade in iOS 27',
#    'description': 'Siri is now directly embedded into the camera app, and there are more artificial intelligence tools in the Photos app to alter your images.',
#    'url': 'https://www.wired.com/story/apples-iphone-camera-app-is-getting-an-ai-upgrade-in-ios-27/',
#    'urlToImage': 'https://media.wired.com/photos/6a270a0e623237895b48f975/191:100/w_1280,c_limit/apple-camera-app-gear-2233007119.jpg',
#    'publishedAt': '2026-06-08T18:40:32Z',
#    'content': 'Your iPhone camera app will look a little different this fall. On Monday at its annual Worldwide Developers Conference in Cupertino, California, Apple showed off new features in its next version of i… [+2335 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Boutayna Chokrane',
#    'title': '2 Best Bluetooth Trackers of 2026, Plus Honorable Mentions',
#    'description': 'Constantly losing your stuff? Here are the best Bluetooth trackers to help you keep everything in check—plus some guidance on staying safe while using them.',
#    'url': 'https://www.wired.com/story/the-best-bluetooth-trackers/',
#    'urlToImage': 'https://media.wired.com/photos/6a232b2b713a46b95a632884/191:100/w_1280,c_limit/The-Best-Bluetooth-Trackers.jpg',
#    'publishedAt': '2026-06-06T10:38:00Z',
#    'content': "I'd like to believe I'm organized. Reality suggests otherwise. I've left my smartphone in the refrigerator and spent hours searching for it. I've misplaced my AirPods and Oura Ring for days at a time… [+2518 chars]"},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Luke Larsen',
#    'title': 'I Never Liked a Laptop Sleeve Until I Tried the Bellroy Laptop Caddy',
#    'description': "The Bellroy Laptop Caddy is actually so much more than a laptop sleeve. With all the extra space and pockets, it's the best laptop companion I've ever used.",
#    'url': 'https://www.wired.com/story/finally-a-laptop-sleeve-for-me/',
#    'urlToImage': 'https://media.wired.com/photos/6a0cabd72c7ee96598e09971/191:100/w_1280,c_limit/Bellroy%20Laptop%20Caddy%20SOURCE%20Bellroy%20(Bag%20Check).jpg',
#    'publishedAt': '2026-05-26T09:32:00Z',
#    'content': 'As we get out of the house, the gear-obsessed WIRED Reviews team is writing about our favorite bags and EDCs. Today, reviewer Luke Larsenraves about his love for his Bellroy Laptop Caddy. You can als… [+2204 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Paresh Dave, Lauren Goode, Zoë Schiffer',
#    'title': 'Meta Employees Are Scrambling to Use Up Benefits Ahead of Layoffs',
#    'description': 'On the eve of about 8,000 jobs being cut, employees are cashing in on headphone stipends and other perks while they still can.',
#    'url': 'https://www.wired.com/story/meta-employees-scramble-benefits-layoffs-ai/',
#    'urlToImage': 'https://media.wired.com/photos/6a0cb2b791b600abc11af14d/191:100/w_1280,c_limit/Meta-Employees-Scrambling-to-Use-Up-Benefits-Ahead-of-Layoffs-Business-2272777092.jpg',
#    'publishedAt': '2026-05-19T19:00:46Z',
#    'content': 'Ahead of Metas latest round of mass layoffs tomorrow, some employees are deserting offices, abandoning their work, and loading up on perks they might soon lose, several people at the company tell WIR… [+2885 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jennifer Pattison Tuohy',
#    'title': 'Cameras get an Apple Intelligence boost in Apple Home',
#    'description': 'Apple Intelligence is coming to cameras connected to Apple Home. At WWDC, Apple announced that with iOS27, the Home app will use Apple Intelligence to analyze footage and generate descriptions summarizing what the camera saw. You can also search footage with …',
#    'url': 'https://www.theverge.com/tech/946032/apple-home-ai-camera-descriptions-search-4k',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Screenshot-2026-06-08-at-1.58.57PM.png?quality=90&strip=all&crop=0%2C3.5746394385138%2C100%2C92.850721122972&w=1200',
#    'publishedAt': '2026-06-08T18:50:04Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSecurity cameras connected to the Home app can use AI to search footage, and HomeKit Secure Video will finally support 4K resolution.\r\nSecurity cameras connected… [+2622 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'Apple announces iOS 27',
#    'description': 'Apple announced its next major iOS update, iOS 27, at WWDC 2026 on Monday. Apple is highlighting performance and design improvements as a major feature, and the update will be supported all the way back to the iPhone 11. A big change is an opacity slider for …',
#    'url': 'https://www.theverge.com/tech/941202/apple-ios-27-wwdc-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/STK071_APPLE_E.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T17:23:57Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nYour iPhone is getting new features.\r\nYour iPhone is getting new features.\r\nby\r\nJay PetersClose\r\nPosts from this author will be added to your daily email digest … [+2895 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'Apple announces iPadOS 27',
#    'description': "Today at Apple's Worldwide Developers Conference, the company announced new features coming to the iPad with iPadOS 27 including optimizations such as apps launching up to 30 percent faster by intelligently preloading needed info, and more responsive switchin…",
#    'url': 'https://www.theverge.com/tech/942546/apple-ipados-27-wwdc-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/ipados1.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T17:51:14Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe iPads next big update is expected to arrive later this year.\r\nThe iPads next big update is expected to arrive later this year.\r\nby\r\nAndrew LiszewskiClose\r\nPo… [+3864 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Robert Hart',
#    'title': 'Apple wants Europe to blink',
#    'description': "It took a few years, but Apple finally made its AI look useful. Now millions of iPhone users in Europe are being told they won't be getting Siri AI anytime soon, if ever - and Apple wants them to blame the EU. Apple says its new AI-powered Siri will not launc…",
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/947051/apple-europe-dma-siri-ai',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/STK450_EU_G.jpg?quality=90&strip=all&crop=0%2C9.9676601489831%2C100%2C80.064679702034&w=1200',
#    'publishedAt': '2026-06-09T17:13:14Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nApple wants Europe to blink\r\nApple blames DMA for delaying Siri AI in Europe. The EU says nothing is stopping Apple from launching it. \r\nby\r\nRobert HartClose\r\nPo… [+7489 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Emma Roth',
#    'title': 'Apple is using AI to fix Safari’s extension problem',
#    'description': "Apple is trying to solve one of Safari's biggest weaknesses with AI. Safari has long lacked the robust library of extensions that its rivals have, mainly due to the stringent development requirements from Apple. But now, Apple is inviting users to essentially…",
#    'url': 'https://www.theverge.com/tech/946345/apple-safari-ai-update-extensions',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/describe-extension-safari.jpg?quality=90&strip=all&crop=0%2C10.742998834307%2C100%2C78.514002331385&w=1200',
#    'publishedAt': '2026-06-08T22:14:17Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSafari will invite users to vibe-code their own extensions.\r\nSafari will invite users to vibe-code their own extensions.\r\nby\r\nEmma RothClose\r\nPosts from this aut… [+4329 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Emma Roth',
#    'title': 'Apple WWDC 2026: The 7 biggest announcements',
#    'description': "Apple's keynote at this year's Worldwide Developers Conference was a big one. After months of delays, Apple reintroduced us to its AI-upgraded Siri, which will go beyond what the existing voice assistant can do by offering more personalized help. We also got …",
#    'url': 'https://www.theverge.com/tech/945693/apple-wwdc-2026-biggest-announcements-ios-27',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Screenshot-2026-06-08-at-1.01.41PM.png?quality=90&strip=all&crop=0%2C2.7453349442878%2C100%2C94.509330111424&w=1200',
#    'publishedAt': '2026-06-08T18:51:19Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe update-filled keynote showed an AI-upgraded Siri along with new features across Apples operating systems.\r\nby\r\nEmma RothClose\r\nPosts from this author will be… [+5329 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jennifer Pattison Tuohy',
#    'title': 'Apple, Google add support for Thread 1.4',
#    'description': 'Apple and Google are updating their smart home streaming devices to Thread 1.4. As first spotted by Matter Alpha and 9to5 Google, the latest spec has arrived on compatible Apple TVs in the tvOS 27 developer beta and the Google TV Streamer through a software u…',
#    'url': 'https://www.theverge.com/tech/947888/apple-google-add-support-for-thread-1-4',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/IMG_7137.jpg?quality=90&strip=all&crop=0%2C30.191972076789%2C100%2C69.808027923211&w=1200',
#    'publishedAt': '2026-06-10T20:30:33Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nIts almost time for one big Thread network!\r\nIts almost time for one big Thread network!\r\nby\r\nJennifer Pattison TuohyClose\r\nSenior Reviewer, Smart Home\r\nPosts fr… [+3614 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Janko Roettgers',
#    'title': 'Is Apple TV the new HBO?',
#    'description': 'This is Lowpass by Janko Roettgers, a newsletter on the ever-evolving intersection of tech and entertainment, syndicated just for The Verge subscribers once a week. Severance. Pachinko. Silo. Ted Lasso. Over the past couple of years, a number of Apple TV show…',
#    'url': 'https://www.theverge.com/column/948295/apple-tv-new-hbo',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/Severance_Photo_020912.jpg?quality=90&strip=all&crop=0%2C10.726247800535%2C100%2C78.54750439893&w=1200',
#    'publishedAt': '2026-06-11T12:19:25Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nUnlike competitors like Netflix, Apple TV emphasizes tentpole titles over large catalogs.\r\nUnlike competitors like Netflix, Apple TV emphasizes tentpole titles o… [+6523 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Antonio G. Di Benedetto',
#    'title': 'Apple announces macOS 27 Golden Gate',
#    'description': "Apple has announced macOS 27 Golden Gate, the next version of its desktop operating system. The new OS for MacBooks and Mac desktops is the follow-up to last year's macOS Tahoe 26. Tahoe added some handy features, like a revised Spotlight search and a Phone a…",
#    'url': 'https://www.theverge.com/tech/943695/apple-wwdc-2026-macos-27-macbook-mac-announcement-features',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/STK071_APPLE_D.webp?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T17:07:30Z',
#    'content': "Apple has announced macOS 27 Golden Gate, the next version of its desktop operating system.\nThe new OS for MacBooks and Mac desktops is the follow-up to last year's macOS Tahoe 26. Tahoe added some h… [+439 chars]"},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Stevie Bonifield',
#    'title': 'Apple announces visionOS 27 with Siri AI',
#    'description': "Along with new software for Macs and iPhones, Apple announced visionOS 27 during its keynote presentation at WWDC on Monday. Like its other platforms, visionOS 27 will feature Apple's updated Siri AI assistant and the new dedicated Siri app. You can use visua…",
#    'url': 'https://www.theverge.com/tech/944129/apple-visionos-updates-wwdc-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wwdc2026-visionos27.png?quality=90&strip=all&crop=0%2C9.6904971505351%2C100%2C80.61900569893&w=1200',
#    'publishedAt': '2026-06-08T18:32:00Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe latest version of Apples mixed reality OS debuts at WWDC.\r\nThe latest version of Apples mixed reality OS debuts at WWDC.\r\nby\r\nStevie BonifieldClose\r\nPosts fr… [+2266 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jess Weatherbed',
#    'title': 'Apple announces watchOS 27, now with Siri AI',
#    'description': 'Apple just announced watchOS 27, the next version of its Apple Watch operating system, introducing support for Siri AI, a redesigned "dynamic" app grid, and improvements to health and fitness tracking. The watchOS 27 update will be available "this fall," acco…',
#    'url': 'https://www.theverge.com/tech/943145/apple-watch-watchos-27-wwdc-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Apple-Watch-watchOS-27-Siri-AI.jpg?quality=90&strip=all&crop=0,14.033409967608,100,71.933180064785',
#    'publishedAt': '2026-06-08T19:34:10Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe upcoming update will be limited to Apples more recent Watch models.\r\nThe upcoming update will be limited to Apples more recent Watch models.\r\nby\r\nJess Weathe… [+4841 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sheena Vasani',
#    'title': 'The Apple Watch Series 11 is back to its best price',
#    'description': 'Apple’s upcoming watchOS 27 update will bring Siri AI and other exciting features to the Apple Watch Series 9 and newer Apple Watch models. If you’re contemplating an upgrade, all colorways of the GPS-enabled 42mm Apple Watch Series 11 — the latest model — ar…',
#    'url': 'https://www.theverge.com/gadgets/947773/apple-watch-series-11-beats-studio-buds-plus-deal-sale',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/12/Apple-Watch-Series-11-deal.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-10T14:57:20Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe slick Beats Studio Buds Plus are also on sale for just $100, and Fujifilms fun Instax Mini 12 is even cheaper.\r\nThe slick Beats Studio Buds Plus are also on … [+4447 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Victoria Song, Nilay Patel',
#    'title': 'WWDC 2026 bonus live blog: Tech Talk with Craig Federighi',
#    'description': 'Fresh off the WWDC keynote presentation, The Verge has been invited to an "on-the-record technical deep dive into the bold new architecture enabling Apple Intelligence capabilities." Apple SVP of Software Engineering Craig Federighi and his team will be there…',
#    'url': 'https://www.theverge.com/tech/946046/wwdc-2026-live-blog-tech-talk-with-craig-federighi',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wwdc-2026-the-verge-55_32.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T18:46:33Z',
#    'content': 'One of the funnier parts of the keynote.\r\n\n\nFresh off the WWDC keynote presentation, The Verge has been invited to an "on-the-record technical deep dive into the bold new architecture enabling Apple … [+915 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'WWDC protesters want Apple to ban Elon Musk’s apps',
#    'description': 'Apple\'s big developer conference is today, and protesters are using the occasion to call on the company to remove "nudify apps" from the App Store and pull "known" child sexual abuse material from iCloud. Outside the visitor\'s center at Apple\'s Cupertino camp…',
#    'url': 'https://www.theverge.com/tech/945813/apple-wwdc-protesters-deepfake-nude-apps-ultraviolet-heat-initiative',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/IMG_1699.jpg?quality=90&strip=all&crop=0%2C15.095986038394%2C100%2C69.808027923211&w=1200',
#    'publishedAt': '2026-06-08T16:37:09Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nTheyre also demanding a crackdown on child abuse imagery in iCloud.\r\nTheyre also demanding a crackdown on child abuse imagery in iCloud.\r\nby\r\nJay PetersClose\r\nPo… [+2186 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Stevie Bonifield',
#    'title': 'The App Store is going to add subscription bundles soon',
#    'description': "Later this year, you will be able to get bundled subscriptions for iPhone apps, as Apple announced it's expanding App Store bundles so they can include offers from different companies. It's similar to streaming video bundles that have combined offers for Appl…",
#    'url': 'https://www.theverge.com/tech/947365/apple-subscription-bundles-app-store',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/23925966/acastro_STK045_01.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-09T21:30:48Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nAlong with iOS 27, Apple also announced big changes to the App Store.\r\nAlong with iOS 27, Apple also announced big changes to the App Store.\r\nby\r\nStevie Bonifiel… [+2188 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Allison Johnson',
#    'title': 'Here comes new Siri again',
#    'description': 'Apple has been on its back foot, AI-wise, for the past few years. But in a strange way, playing from behind might not be such a bad move. At WWDC on Monday, Apple appears to be getting ready to reintroduce us to the new Siri. Again. As a reminder, we met the …',
#    'url': 'https://www.theverge.com/tech/944245/apple-wwdc-2026-ai-siri-gemini',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wwdc_2024.jpg?quality=90&strip=all&crop=0%2C10.597538331207%2C100%2C78.804923337586&w=1200',
#    'publishedAt': '2026-06-05T18:40:17Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nHere comes new Siri again\r\nIts time for a re-reintroduction.\r\nby\r\nAllison JohnsonClose\r\nPosts from this author will be added to your daily email digest and your … [+5969 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Stevie Bonifield',
#    'title': 'WWDC 2026: All the news from Apple’s developers conference',
#    'description': 'Apple’s annual WWDC event is kicking off on June 8th with a keynote presentation starting at 1PM ET / 10AM PT, where Apple will announce major updates to iOS, macOS, and its other operating systems.\xa0 Among those updates could be Apple’s delayed Siri overhaul,…',
#    'url': 'https://www.theverge.com/tech/944110/wwdc-2026-news-announcements',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/STK071_APPLE_E.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T16:05:33Z',
#    'content': 'Apples annual WWDC event is kicking off on June 8th with a keynote presentation starting at 1PM ET / 10AM PT, where Apple will announce major updates to iOS, macOS, and its other operating systems.\r\n… [+2748 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Stevie Bonifield',
#    'title': 'WWDC 2026: How to watch and what to expect',
#    'description': "Apple's biggest event of the year is nearly here. The company's Worldwide Developers Conference will spotlight updates to iOS, macOS, and all of Apple's other operating systems, and this year's event could also include a major overhaul for Siri. Here's how yo…",
#    'url': 'https://www.theverge.com/tech/944099/wwdc-2026-how-to-watch',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/unnamed-8.jpg?quality=90&strip=all&crop=0%2C18.517948191493%2C100%2C62.964103617014&w=1200',
#    'publishedAt': '2026-06-06T22:12:51Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nApples annual developer conference kicking off on June 8th could include a long-awaited Siri upgrade.\r\nApples annual developer conference kicking off on June 8th… [+3449 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'John.Higgins',
#    'title': 'Where was tvOS 27 at WWDC?',
#    'description': 'Every year, Apple\'s Worldwide Developers Conference gives us a first look at what\'s coming next to the company\'s many operating systems. But missing from today\'s keynote, apart from a single graphic listing all current Apple OSes next to a big "27," was any m…',
#    'url': 'https://www.theverge.com/tech/946329/tvos-27-absent-wwdc',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/22541100/DSCF3875_2.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T22:04:42Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nWith a focus on features instead of OS, tvOS 27 was only mentioned briefly in a quick presentation slide.\r\nWith a focus on features instead of OS, tvOS 27 was on… [+3594 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Lauren Feiner',
#    'title': 'Apple’s new parental controls are for keeping Apple out of trouble',
#    'description': "When Apple put child safety front and center at WWDC on Monday, its stated goal was helping parents fine-tune their kids' online experiences and avoid excessive screen time. But amid a global debate over internet regulation, its latest updates also looked lik…",
#    'url': 'https://www.theverge.com/policy/946331/apple-parental-controls-child-accounts-wwdc',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/02/STKS526_SOCIAL_MEDIA_TRIAL_CVIRGINIA_D.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T21:48:08Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nApple expanded its toolkit for parents at WWDC, but pushed developers to step up.\r\nApple expanded its toolkit for parents at WWDC, but pushed developers to step … [+6091 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew J. Hawkins',
#    'title': 'Jony Ive’s Ferrari looks nothing like a Ferrari',
#    'description': "Ferrari makes some of the fastest cars on the planet, so it's anyone's guess how the Italian automaker ended up being so incredibly late to the EV party. Long after most automakers have drastically scaled back their EV ambitions, cancelled battery-powered mod…",
#    'url': 'https://www.theverge.com/transportation/937077/ferrari-luce-ev-apple-car-jony-ive-design',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Luce_30rtv4_lightson_1x1hr_d955d06c-1be5-4001-99e2-55ce7e65f960_4a4d75.jpg?quality=90&strip=all&crop=0%2C22.665645835327%2C100%2C53.446325992659&w=1200',
#    'publishedAt': '2026-05-26T16:22:59Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nJony Ives Ferrari looks nothing like a Ferrari\r\nFerrari fans are losing it.\r\nby\r\nAndrew J. HawkinsClose\r\nPosts from this author will be added to your daily email… [+8773 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'Apple’s best AI idea looks a lot like vibe coding',
#    'description': "Most of Apple's current AI ideas are roughly the same as everyone else's AI ideas. A chatbot you can ask questions; quick ways to create or summarize text; bizarre, borderline creepy image-generation tools. The company spent most of its WWDC keynote playing c…",
#    'url': 'https://www.theverge.com/tech/946733/apple-shortcuts-ai-safari-tabs-vibe-code',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/AI-Apple-Shortcuts.jpg?quality=90&strip=all&crop=0%2C3.3555449785816%2C100%2C93.288910042837&w=1200',
#    'publishedAt': '2026-06-09T13:34:48Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nApples best AI idea looks a lot like vibe coding\r\nSiri AI and Image Playground will get all the hype, but Apple can actually make our lives better in Safari and … [+7449 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Richard Lawler',
#    'title': 'Apple’s accessibility features add more AI-powered processing',
#    'description': "Apple's annual update about accessibility features on its platforms has new additions for the iPhone, Mac, and especially Vision Pro, with a focus on how on-device AI processing is being used in features like VoiceOver, Magnifier, Voice Control, and Accessibi…",
#    'url': 'https://www.theverge.com/tech/933420/apple-iphone-mac-vision-pro-accessibility-2026-apple-intelligence',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Apple-accessibility-features-Magnifier.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-19T14:58:12Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nApples adding AI-generated subtitling for any video.\r\nApples adding AI-generated subtitling for any video.\r\nby\r\nRichard LawlerClose\r\nPosts from this author will … [+2739 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sean Hollister',
#    'title': 'Nvidia announces RTX Spark as ‘the most efficient PC chip ever built’',
#    'description': "This fall, Nvidia will officially become a consumer PC chipmaker like Intel, AMD, Apple, and Qualcomm, putting a complete computing chip - not just graphics - into the very heart of laptops and mini-PCs. After many months of leaks, it's finally announcing the…",
#    'url': 'https://www.theverge.com/tech/940589/nvidia-rtx-spark-n1-n1x-laptop-desktop-pc-cpu-gpu-ai-release-date',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/spark.jpg?quality=90&strip=all&crop=13.2,23.707517114377,86.8,58.222136995036',
#    'publishedAt': '2026-06-01T04:34:59Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nNvidia enters the consumer laptop realm.\r\nNvidia enters the consumer laptop realm.\r\nby\r\nSean HollisterClose\r\nPosts from this author will be added to your daily e… [+8779 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'Siri is good now??',
#    'description': 'You\'d be forgiven for thinking this day would never come. Siri has spent a decade and half somewhere between "sort of useful at a few things" and "utterly disastrous, why did I even try, can it honestly not even set a timer." But the wildest thing just happen…',
#    'url': 'https://www.theverge.com/podcast/949079/siri-ai-good-vergecast',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/VST_0612_Site.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-12T17:17:04Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nOn The Vergecast: Our first days with Siri AI, the next phase of social networks, and the Trump Phones a ripoff.\r\nOn The Vergecast: Our first days with Siri AI, … [+3128 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'Ugreen’s new soccer ball-shaped tracker has up to 7 years of battery life',
#    'description': 'Ugreen has announced a new Apple Find My-compatible tracker with a novel design that limits where you can hide it, but greatly benefits battery life. Inspired by "major football tournaments" the company doesn\'t call out by name, the Ugreen FineTrack 2 is shap…',
#    'url': 'https://www.theverge.com/tech/934101/ugreen-finetrack-2-mini-tracker-apple-find-my-soccer-ball',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/ugreen1.jpg?quality=90&strip=all&crop=0,10.732984293194,100,78.534031413613',
#    'publishedAt': '2026-05-19T19:49:11Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nBut when its non-replaceable battery finally dies, youll need to kick the FineTrack 2 into the e-waste bin.\r\nBut when its non-replaceable battery finally dies, y… [+2481 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Terrence O’Brien',
#    'title': 'Deezer launches an AI music detector for other streaming services',
#    'description': "Deezer will now scan your playlists on other streaming platforms to detect AI-generated music. Deezer was the first of the big streaming services to start labeling AI-generated music. It even offered its tech to other platforms, but it doesn't seem like it ha…",
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/948153/deezer-ai-music-detector-spotify-apple',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/NEW_1200-x-580-pixel-SI-logo-1240x600-1.jpeg?quality=90&strip=all&crop=3.7903225806452,0,92.41935483871,100',
#    'publishedAt': '2026-06-10T23:42:48Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSince the competition wont buy their tech, theyre bringing it directly to users.\r\nSince the competition wont buy their tech, theyre bringing it directly to users… [+2359 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Antonio G. Di Benedetto',
#    'title': 'My first 24 hours with Siri AI on the Mac',
#    'description': "I turned off Siri on the Mac years ago and never looked back. Similarly, I found Apple Intelligence so fruitless I never engage with it. But the new Siri AI coming to macOS 27 Golden Gate has at least got me slightly rethinking things. I'm still early in test…",
#    'url': 'https://www.theverge.com/tech/949502/apple-macos-27-golden-gate-siri-ai-apple-intelligence',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/061326_Siri_AI_MacBook_Pro_macOS_27_Golden_Gate_beta_ADiBenedetto_0003.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-13T13:44:07Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nMy first 24 hours with Siri AI on the Mac\r\nSiri is better, but its limitations are much more obvious on a Mac than an iPhone.\r\nby\r\nAntonio G. Di BenedettoClose\r\n… [+8253 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'John.Higgins',
#    'title': 'The three sets of earbuds I reach for',
#    'description': 'I have been an audio reviewer for 20 years. My time as a freelance headphones panelist at Wirecutter, and the multitude of reviews I’ve written for sites like Reviewed, Digital Trends, IGN, and now The Verge, have given me the chance to listen to hundreds of …',
#    'url': 'https://www.theverge.com/gadgets/947325/three-earbuds-i-consistently-use',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/268563_go-to_earbuds_JHiggins_0001.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-09T22:21:07Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nEarbuds come and go in the life of a reviewer, but these three have earned permanent spots in my life.\r\nIf you buy something from a Verge link, Vox Media may ear… [+8009 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': '5 things I already love from the iOS 27 beta',
#    'description': "iOS 27 has only been out for a few hours, and I've been messing around with the developer beta on my iPhone 16 Pro. I was most interested in trying out the new Siri AI, but unfortunately, I'm still on Apple's waitlist for that. In the meantime, I've been poki…",
#    'url': 'https://www.theverge.com/tech/946391/apple-ios-27-developer-beta-1-wwdc-2026-5-things',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/videoframe_560765.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2026-06-08T23:30:32Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nLike better icons and chonky widgets.\r\nLike better icons and chonky widgets.\r\nby\r\nJay PetersClose\r\nPosts from this author will be added to your daily email diges… [+3811 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Allison Johnson',
#    'title': 'I tried Siri AI, and so far it actually works',
#    'description': 'Parents want one thing, and one thing only, out of AI: to add a list of soccer games or "spirit week" theme days from an email or a poorly formatted flyer onto their calendar in one shot. And I have good news for parents with iPhones - the new Siri can finall…',
#    'url': 'https://www.theverge.com/tech/947432/siri-ai-apple-intelligence-ios-27-wwdc',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/DSC03775_processed.jpg?quality=90&strip=all&crop=0%2C10.723165084465%2C100%2C78.55366983107&w=1200',
#    'publishedAt': '2026-06-09T23:33:14Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nIts basic, but it works is a big deal.\r\nby\r\nAllison JohnsonClose\r\nPosts from this author will be added to your daily email digest and your homepage feed.\r\nFollow… [+5952 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'Apple’s new Siri AI knows when to shut up',
#    'description': "Apple's new Siri AI is finally here, and so far, it seems like it works. I have access and have been messing around with it, and my biggest impression so far is that Siri AI is quite curt - which I mean as a compliment. Many AI chatbots are cheery and wordy. …",
#    'url': 'https://www.theverge.com/tech/948155/apple-siri-ai-chatbot-personality',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/videoframe_13193.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2026-06-10T22:52:17Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSiri AI keeps things brief.\r\nSiri AI keeps things brief.\r\nby\r\nJay PetersClose\r\nPosts from this author will be added to your daily email digest and your homepage … [+5345 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'I have a new go-to browser',
#    'description': "Hi, friends! Welcome to Installer No. 129, your guide to the best and Verge-iest stuff in the world. (If you're new here, welcome, come on you Gunners, and also you can read all the old editions at the Installer homepage.) This week, I've mostly been sick, wh…",
#    'url': 'https://www.theverge.com/tech/936395/vivaldi-8-review-mandalorian-installer',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Installer-129.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-22T18:18:56Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nPlus, in this weeks Installer: The latest big thing from Star Wars, a couple of tech reads, and some Apple Shortcuts.\r\nPlus, in this weeks Installer: The latest … [+8654 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Brad Bourque',
#    'title': 'Motorola’s last-gen Razr Ultra is almost half off',
#    'description': 'Motorola’s latest Razr Ultra proves that its flip foldable format has evolved to become more than just a nostalgic gimmick. I’d understand if you’re not interested in shelling out $1,499.99 for the 2026 model, but the similar 2025 Motorola Razr Ultra with 512…',
#    'url': 'https://www.theverge.com/gadgets/938621/razr-ultra-roborock-qrevo-curv-2-robot-vacuum-deal-sale',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/moto-razr-2025-deal-image.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-28T18:33:08Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nPlus, a Roborock robot vacuum and mop we like is $100 off, and AirPods Max 2 are discounted.\r\nPlus, a Roborock robot vacuum and mop we like is $100 off, and AirP… [+3966 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Lauren Feiner',
#    'title': 'Microsoft could be the next Big Tech antitrust target',
#    'description': 'Over the past several years, Microsoft has largely managed to withstand populist calls to break up Big Tech while peers faced sweeping lawsuits. But a probe by the Federal Trade Commission suggests that grace period could be nearing an end. Earlier this year,…',
#    'url': 'https://www.theverge.com/policy/940220/microsoft-ftc-antitrust-investigation-cloud-ai',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/STKS530_FTC_Microsoft_AParkin3.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-01T13:23:39Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nAfter 25 years, an FTC investigation could put it back in the hot seat.\r\nAfter 25 years, an FTC investigation could put it back in the hot seat.\r\nby\r\nLauren Fein… [+9631 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sheena Vasani, Cameron Faulkner',
#    'title': 'The best Memorial Day sales you can shop this weekend',
#    'description': 'Memorial Day is nearly here, meaning the seasonal sales are in full swing. If your weekend plans involve pool parties or barbecues, now is a great time to pick up a portable speaker or set of solar lights, as many of our favorite models are currently on sale.…',
#    'url': 'https://www.theverge.com/gadgets/936196/best-memorial-day-sales-tech-deals-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/09/257943_Airpods_Pro3_AKrales_0103.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-22T16:50:38Z',
#    'content': 'Memorial Day is nearly here, meaning the seasonal sales are in full swing. If your weekend plans involve pool parties or barbecues, now is a great time to pick up a portable speaker or set of solar l… [+30889 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'The new Halide camera app launches with film looks and an upgraded photo editor',
#    'description': "After first being announced in December 2024, Lux Optics has finally released the latest version of its Halide camera app for the iPhone and iPad. The Halide Mark III app's most compelling feature is a new film simulation engine and a collection of five new L…",
#    'url': 'https://www.theverge.com/tech/938339/lux-optics-halide-mark-iii-ios-iphone-camera-app-looks-editor-raw-files-now-available',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/halidecamera1.jpg?quality=90&strip=all&crop=0%2C10.765679560227%2C100%2C78.468640879546&w=1200',
#    'publishedAt': '2026-05-27T20:06:12Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nHalide Mark III includes five unique looks and an upgraded photo editor that can process RAW files from other cameras.\r\nHalide Mark III includes five unique look… [+3511 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sheena Vasani',
#    'title': 'Apple’s latest MacBook Air is $200 off in both sizes for Memorial Day',
#    'description': 'If you’re looking for a laptop that’ll still perform well several years from now, Apple’s latest MacBook Air is hard to beat. Now, in particular, is a good time to pick one up, as you can currently buy the 13-inch MacBook Air at Amazon in the run-up to Memori…',
#    'url': 'https://www.theverge.com/gadgets/936610/apple-macbook-air-m5-memorial-day-2026-deal-sale',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/268408_Apple_MacBook_Air_15_M5_laptop_ADiBenedetto_0026.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-24T14:56:48Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe M5 Air is fast enough for everyday tasks and then some, which is why its our top laptop rec for most people.\r\nThe M5 Air is fast enough for everyday tasks an… [+3042 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'The post-search Google era begins',
#    'description': "Google is many things, but most of the time it's a verb: It is what it is to search the internet for information. But what if it's an AI agent doing the searching? And it's doing it proactively? Without even telling you about it? In the world Google imagines,…",
#    'url': 'https://www.theverge.com/podcast/936037/google-io-2026-search-agents-vergecast',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/VRG_VST_0522_Site.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-22T13:47:41Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nOn The Vergecast: The AI will Google for you now, the Trump Phone is real, and SpaceX is SpaceT-Mobile.\r\nOn The Vergecast: The AI will Google for you now, the Tr… [+3113 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'Sennheiser’s new Momentum 5 headphones have upgraded ANC and a replaceable battery',
#    'description': "Nearly four years after the last version of Sennheiser's Momentum headphones debuted with a redesign that traded a retro aesthetic for a more contemporary and comfortable design, the company has announced its Momentum 5 Wireless headphones. They look very sim…",
#    'url': 'https://www.theverge.com/tech/936127/sennheiser-momentum-5-wireless-headphones-anc-lossless-bluetooth',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/sennheiser1.jpg?quality=90&strip=all&crop=0%2C10.740836125969%2C100%2C78.518327748063&w=1200',
#    'publishedAt': '2026-05-22T16:29:51Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nDouble the microphones means better noise canceling and call quality.\r\nDouble the microphones means better noise canceling and call quality.\r\nby\r\nAndrew Liszewsk… [+3305 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jacob Kastrenakes',
#    'title': 'We react to Google I/O 2026',
#    'description': "What better way to unwind from a two-hour-long keynote presentation than to pour over the weirdest and wildest details, from a Gmail bot you can converse with to DeepMind's leader saying the singularity is near. The Vergecast went live right after the show, w…",
#    'url': 'https://www.theverge.com/podcast/934202/we-react-to-google-i-o-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/20260519_VCthumb_v2.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2026-05-19T21:48:26Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nby\r\nJacob KastrenakesClose\r\nPosts from this author will be added to your daily email digest and your homepage feed.\r\nFollow\r\nFollowSee All by Jacob Kastrenakes\r\n… [+3047 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sheena Vasani',
#    'title': 'Here are our favorite Memorial Day tech deals so far',
#    'description': 'Memorial Day marks the unofficial start of summer, and the holiday’s sales include plenty of deals on gadgets that can help you make the most of the season. If your plans involve beach days, pool parties, or backyard barbecues, now’s a great time to pick up a…',
#    'url': 'https://www.theverge.com/gadgets/932465/best-memorial-day-sales-deals-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/jbl_charge6_flip7_1.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-19T20:25:09Z',
#    'content': 'Portable bluetooth speakers like the Charge 6 and Flip 7 are just a few on sale for Memorial Day.\r\n\n\nMemorial Day marks the unofficial start of summer, and the holiday’s sales include plenty of deals… [+25369 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Dominic Preston',
#    'title': 'User-replaceable batteries are coming back in a big way',
#    'description': "This is The Stepback, a weekly newsletter breaking down one essential story from the tech world. For more news about gadgets and smartphones, follow Dominic Preston. The Stepback arrives in our subscribers' inboxes at 8AM ET. Opt in for The Stepback here. How…",
#    'url': 'https://www.theverge.com/column/939026/user-replaceable-batteries-eu-european-union-legislation',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/24647291/236644_Fairbuds_XL_JPorter_0012.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-29T12:32:55Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethics statement.\r\nby\r\nDominic PrestonClose\r\nPosts from this author will be adde… [+13922 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Robert Hart',
#    'title': 'Tech companies desperately want to film you doing chores',
#    'description': "This week, an AI training startup called Shift said it would clean New Yorkers' homes for free. It has plans to expand into other cities as well, including London, and looking around my flat, I get the appeal. But there's a catch. There's always a catch. In e…",
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/940007/ai-companies-will-pay-for-robot-training-data',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/STK414_AI_CVIRGINIA_I__0009_7.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-29T17:37:43Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nStartups are paying people for the real-world data needed to train their robots. \r\nStartups are paying people for the real-world data needed to train their robot… [+5060 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Allison Johnson',
#    'title': 'Vibe coding is coming to your phone',
#    'description': '"There\'s an app for that" was the promise of the App Store from the very beginning. The app that will get your phone to do the thing you want it to? It\'s just a few taps away. The tagline wasn\'t strictly true - I\'m still waiting for that one perfect grocery l…',
#    'url': 'https://www.theverge.com/tech/934628/google-io-2026-android-ai-studio-widgets-shortcuts',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/10/258002_Google_Pixel_10_Pro_Fold_AJohnson_0010.jpg?quality=90&strip=all&crop=0%2C10.723165084465%2C100%2C78.55366983107&w=1200',
#    'publishedAt': '2026-05-20T17:37:21Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nPersonal tech is about to get a lot more personal.\r\nPersonal tech is about to get a lot more personal.\r\nby\r\nAllison JohnsonClose\r\nPosts from this author will be … [+5291 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'TC. Sottek',
#    'title': 'As AI gets better, it reveals an empty promise',
#    'description': "This week we've got tandem hands-ons with Google's new Gemini AI agent - Spark - from my colleagues David Pierce and Jay Peters. Their takeaways are similar: It's so effective that it's scary. Spark knew that David's dog is named Frida and knew the first name…",
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/942629/as-ai-gets-better-it-reveals-an-empty-promise',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/11503853/mdoying_180419_1777_0454_2.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-03T17:47:27Z',
#    'content': '<ul><li></li></ul>\r\nYour new assistant can schedule a meeting but it cant fix our broken world.\r\nYour new assistant can schedule a meeting but it cant fix our broken world.\r\nby\r\nTC SottekClose\r\nPosts… [+5443 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'John.Higgins',
#    'title': 'WiiM expands its whole-home ecosystem with a new soundbar',
#    'description': "WiiM, the audio company that's challenged the idea that audiophile-level performance requires a small loan, is expanding its whole-home ecosystem with the WiiM Bar, which releases in July. Much like its other speakers and audio components, the WiiM Bar suppor…",
#    'url': 'https://www.theverge.com/tech/942748/wiim-releases-first-soundbar',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wiim-bar-lifestyle.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-03T21:12:51Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe company is known for making high-quality, inexpensive audio products, and the WiiM Bar is its first home theater speaker.\r\nThe company is known for making hi… [+3635 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Terrence O’Brien',
#    'title': 'Feeble Little Horse leans into digital weirdness on bitknot',
#    'description': "From the opening moments of bitknot, it's obvious that Feeble Little Horse has found an entirely new gear. Where on Girl with Fish the blown-out textures were more '90s indie rock and shoegaze, on their latest LP, there's a more modern edge to the distortion …",
#    'url': 'https://www.theverge.com/entertainment/940449/feeble-little-horse-bitknot-music-album-review',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Feeble-Little-Horse-bitknot.jpg?quality=90&strip=all&crop=5.4333333333333%2C0%2C89.133333333333%2C100&w=1200',
#    'publishedAt': '2026-05-30T18:11:18Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe band has evolved from exciting indie rock throwback into something more cutting-edge.\r\nThe band has evolved from exciting indie rock throwback into something… [+4314 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'Boox’s quirky page-turning remote won me over',
#    'description': 'Following the launch of the surprisingly popular Kobo Remote, Boox has released its own device to ease the burden of reaching for an e-reader’s touchscreen that’s an arm’s length away. The Tappy isn’t Boox’s first page-turning remote, but its design takes a m…',
#    'url': 'https://www.theverge.com/tech/943699/slug-boox-tappy-wireless-bluetooth-remote-page-turn-android-ios-hands-on',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/booxtappy7.jpg?quality=90&strip=all&crop=0%2C10.740836125969%2C100%2C78.518327748063&w=1200',
#    'publishedAt': '2026-06-10T14:15:18Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nUnlike the Kobo Remote, Booxs Tappy also works with iPhones, Android devices, and other e-readers.\r\nUnlike the Kobo Remote, Booxs Tappy also works with iPhones, … [+6170 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Victoria Song',
#    'title': '‘Solve all diseases,’ you say?',
#    'description': "This is Optimizer, a weekly newsletter sent from Verge senior reviewer Victoria Song that dissects and discusses the latest gizmos and potions that swear they're going to change your life. This week's issue is a special early edition tied to The Verge's Googl…",
#    'url': 'https://www.theverge.com/column/935021/google-io-gemini-for-science-alphafold-alphagenome-ai-health',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/demishassabis.webp?quality=90&strip=all&crop=0%2C10.597538331207%2C100%2C78.804923337586&w=1200',
#    'publishedAt': '2026-05-20T21:06:35Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nGoogle DeepMind CEO Demis Hassabis made a bold claim at this years I/O keynote. Not so fast!\r\nby\r\nVictoria SongClose\r\nSenior Reviewer, Wearable Tech\r\nPosts from … [+9375 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Lauren Feiner',
#    'title': 'America’s dangerous, messy deepfakes crackdown is here',
#    'description': 'A law requiring social networks to quickly remove sexual deepfakes and other nonconsensual imagery is now fully in force. But experts warn the policy could do little to help victims - and at worst could facilitate censorship online. Last May, President Donald…',
#    'url': 'https://www.theverge.com/policy/933518/take-it-down-act-notice-removal-social-media-deepfake',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/STK419_DEEPFAKE_3_CVIRGINIA_C.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-19T14:58:19Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe Take It Down Act is in full force, but it could be a gift to government censors not victims of image-based sexual abuse.\r\nThe Take It Down Act is in full for… [+7991 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Thomas Ricker',
#    'title': 'Solid-state batteries still aren’t ready, but gels are',
#    'description': "This is The Stepback, a weekly newsletter breaking down one essential story from the tech world. For more on e-bikes, power stations, and how to work anywhere, follow Thomas Ricker. The Stepback arrives in our subscribers' inboxes at 8AM ET. Opt in for The St…",
#    'url': 'https://www.theverge.com/column/948594/solid-state-batteries-semi-solid-state',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/268587_Stepback_solid_state__CVirginia.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-14T05:48:21Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSemi-solid state batteries are a less volatile bridge to the future.\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethics sta… [+8750 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Antonio G. Di Benedetto',
#    'title': 'If I could only have one laptop for work and gaming, I’d get this one',
#    'description': "I've loved the Asus ROG Zephyrus G14 since it launched in 2020. I bought one for my wife after reading about how awesome it was on a little site called The Verge dot com. Since then, the G14 has gotten some facelifts, chip bumps, an occasional special edition…",
#    'url': 'https://www.theverge.com/tech/935898/asus-rog-zephyrus-g14-2026-intel-nvidia-review',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/268552_Asus_ROG_Zephyrus_G14_2026_Intel_ADiBenedetto_0012.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-22T13:01:59Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe new Asus ROG Zephyrus G14 is almost perfect for me, except its $3,600.\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethi… [+15012 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sean Hollister',
#    'title': '‘Fuck you, Bambu’: How one private message could change the face of 3D printing',
#    'description': 'Bambu Lab makes the best, most accessible 3D printers yet, but that reputation is suddenly under siege. It all started when Paweł Jarczak received a private message from the company on Reddit asking him to delete his code. Now the 3D printing community is lin…',
#    'url': 'https://www.theverge.com/tech/931532/bambu-agpl-pawel-jarczak-open-source-threat-dmca-github',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/11/bambu_lab1.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-20T22:02:02Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nFuck you, Bambu: How one private message could change the face of 3D printing\r\nBambu was set to become the Apple of 3D printers. Then it DMd the wrong person.\r\nb… [+19057 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'The next YouTube phenomenon hitting the big screen',
#    'description': "Hi, friends! Welcome to Installer No. 131, your guide to the best and Verge-iest stuff in the world. (If you're new here, welcome, happy last week of productivity before the World Cup starts, and also you can read all the old editions at the Installer homepag…",
#    'url': 'https://www.theverge.com/tech/944942/amazing-digital-circus-lego-pokemon-installer',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Verge-Tools-Installer.png?quality=90&strip=all&crop=0%2C10.788682187813%2C100%2C78.422635624373&w=1200',
#    'publishedAt': '2026-06-06T02:13:05Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nPlus, in this weeks Installer: More ways to play Final Fantasy, an awesome set of smart Legos, and much more.\r\nPlus, in this weeks Installer: More ways to play F… [+11921 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Nilay Patel',
#    'title': 'Rivian’s software chief thinks you don’t need CarPlay or buttons',
#    'description': 'Today, I’m talking with Wassym Bensaid, the chief software officer at Rivian, and the co-CEO of Rivian’s platform joint venture with Volkswagen, which everyone just calls RV Tech. That joint venture kicked off about a year and a half ago with a nearly $6 bill…',
#    'url': 'https://www.theverge.com/podcast/929940/rivian-wassym-bensaid-software-volkswagen-carplay-assistant-ai',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/DCD-Wassym-Bensaid.png?quality=90&strip=all&crop=0%2C10.711631919237%2C100%2C78.576736161526&w=1200',
#    'publishedAt': '2026-05-28T14:03:31Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nWassym Bensaid on why AI-powered voice control should be the future interface of car software.\r\nby\r\nNilay PatelClose\r\nPosts from this author will be added to you… [+55367 chars]'}]}

# %%
data = response.json()
type(data)
data
# Out:
# {'status': 'ok',
#  'totalResults': 37427,
#  'articles': [{'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Louryn Strampe',
#    'title': 'Memorial Day Tech Deals: Sony, Apple, Beats (2026)',
#    'description': 'Lots of our most-recommended headphones, power banks, and other gadgets are on sale for Memorial Day.',
#    'url': 'https://www.wired.com/story/memorial-day-tech-deals-2026-1/',
#    'urlToImage': 'https://media.wired.com/photos/6a06188db84b146a9eec38c1/191:100/w_1280,c_limit/Memorial%20Day%20Deals%20Tech%20top%20art%20052026%20SOURCE%20Amazon.jpg',
#    'publishedAt': '2026-05-22T18:52:47Z',
#    'content': "When you think of Memorial Day sales, you probably think of mattresses and other home goods. And while those items are definitely discounted, now is also a good time to purchase tech. Personally, I'm… [+1064 chars]"},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Luke Larsen',
#    'title': 'MacOS 27 Golden Gate: Top New Features',
#    'description': "Apple has announced the latest version of macOS. It's all about the reintroduction of Siri, which is now accessible from anywhere on the Mac desktop.",
#    'url': 'https://www.wired.com/story/macos-27-golden-gate-top-features/',
#    'urlToImage': 'https://media.wired.com/photos/6a2849c20d6aa02c6a8cdf9e/191:100/w_1280,c_limit/Apple-OS-27-updates-260608.jpg',
#    'publishedAt': '2026-06-09T17:33:21Z',
#    'content': 'One of the most interesting new features is Custom Extensions, which lets you create an extension for Safari in natural language. Lastly, the new version of Safari will work the Passwords app to auto… [+2328 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Julian Chokkattu',
#    'title': 'Apple’s iPhone Camera App Is Getting an AI Upgrade in iOS 27',
#    'description': 'Siri is now directly embedded into the camera app, and there are more artificial intelligence tools in the Photos app to alter your images.',
#    'url': 'https://www.wired.com/story/apples-iphone-camera-app-is-getting-an-ai-upgrade-in-ios-27/',
#    'urlToImage': 'https://media.wired.com/photos/6a270a0e623237895b48f975/191:100/w_1280,c_limit/apple-camera-app-gear-2233007119.jpg',
#    'publishedAt': '2026-06-08T18:40:32Z',
#    'content': 'Your iPhone camera app will look a little different this fall. On Monday at its annual Worldwide Developers Conference in Cupertino, California, Apple showed off new features in its next version of i… [+2335 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Boutayna Chokrane',
#    'title': '2 Best Bluetooth Trackers of 2026, Plus Honorable Mentions',
#    'description': 'Constantly losing your stuff? Here are the best Bluetooth trackers to help you keep everything in check—plus some guidance on staying safe while using them.',
#    'url': 'https://www.wired.com/story/the-best-bluetooth-trackers/',
#    'urlToImage': 'https://media.wired.com/photos/6a232b2b713a46b95a632884/191:100/w_1280,c_limit/The-Best-Bluetooth-Trackers.jpg',
#    'publishedAt': '2026-06-06T10:38:00Z',
#    'content': "I'd like to believe I'm organized. Reality suggests otherwise. I've left my smartphone in the refrigerator and spent hours searching for it. I've misplaced my AirPods and Oura Ring for days at a time… [+2518 chars]"},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Luke Larsen',
#    'title': 'I Never Liked a Laptop Sleeve Until I Tried the Bellroy Laptop Caddy',
#    'description': "The Bellroy Laptop Caddy is actually so much more than a laptop sleeve. With all the extra space and pockets, it's the best laptop companion I've ever used.",
#    'url': 'https://www.wired.com/story/finally-a-laptop-sleeve-for-me/',
#    'urlToImage': 'https://media.wired.com/photos/6a0cabd72c7ee96598e09971/191:100/w_1280,c_limit/Bellroy%20Laptop%20Caddy%20SOURCE%20Bellroy%20(Bag%20Check).jpg',
#    'publishedAt': '2026-05-26T09:32:00Z',
#    'content': 'As we get out of the house, the gear-obsessed WIRED Reviews team is writing about our favorite bags and EDCs. Today, reviewer Luke Larsenraves about his love for his Bellroy Laptop Caddy. You can als… [+2204 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Paresh Dave, Lauren Goode, Zoë Schiffer',
#    'title': 'Meta Employees Are Scrambling to Use Up Benefits Ahead of Layoffs',
#    'description': 'On the eve of about 8,000 jobs being cut, employees are cashing in on headphone stipends and other perks while they still can.',
#    'url': 'https://www.wired.com/story/meta-employees-scramble-benefits-layoffs-ai/',
#    'urlToImage': 'https://media.wired.com/photos/6a0cb2b791b600abc11af14d/191:100/w_1280,c_limit/Meta-Employees-Scrambling-to-Use-Up-Benefits-Ahead-of-Layoffs-Business-2272777092.jpg',
#    'publishedAt': '2026-05-19T19:00:46Z',
#    'content': 'Ahead of Metas latest round of mass layoffs tomorrow, some employees are deserting offices, abandoning their work, and loading up on perks they might soon lose, several people at the company tell WIR… [+2885 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jennifer Pattison Tuohy',
#    'title': 'Cameras get an Apple Intelligence boost in Apple Home',
#    'description': 'Apple Intelligence is coming to cameras connected to Apple Home. At WWDC, Apple announced that with iOS27, the Home app will use Apple Intelligence to analyze footage and generate descriptions summarizing what the camera saw. You can also search footage with …',
#    'url': 'https://www.theverge.com/tech/946032/apple-home-ai-camera-descriptions-search-4k',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Screenshot-2026-06-08-at-1.58.57PM.png?quality=90&strip=all&crop=0%2C3.5746394385138%2C100%2C92.850721122972&w=1200',
#    'publishedAt': '2026-06-08T18:50:04Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSecurity cameras connected to the Home app can use AI to search footage, and HomeKit Secure Video will finally support 4K resolution.\r\nSecurity cameras connected… [+2622 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'Apple announces iOS 27',
#    'description': 'Apple announced its next major iOS update, iOS 27, at WWDC 2026 on Monday. Apple is highlighting performance and design improvements as a major feature, and the update will be supported all the way back to the iPhone 11. A big change is an opacity slider for …',
#    'url': 'https://www.theverge.com/tech/941202/apple-ios-27-wwdc-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/STK071_APPLE_E.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T17:23:57Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nYour iPhone is getting new features.\r\nYour iPhone is getting new features.\r\nby\r\nJay PetersClose\r\nPosts from this author will be added to your daily email digest … [+2895 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'Apple announces iPadOS 27',
#    'description': "Today at Apple's Worldwide Developers Conference, the company announced new features coming to the iPad with iPadOS 27 including optimizations such as apps launching up to 30 percent faster by intelligently preloading needed info, and more responsive switchin…",
#    'url': 'https://www.theverge.com/tech/942546/apple-ipados-27-wwdc-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/ipados1.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T17:51:14Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe iPads next big update is expected to arrive later this year.\r\nThe iPads next big update is expected to arrive later this year.\r\nby\r\nAndrew LiszewskiClose\r\nPo… [+3864 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Robert Hart',
#    'title': 'Apple wants Europe to blink',
#    'description': "It took a few years, but Apple finally made its AI look useful. Now millions of iPhone users in Europe are being told they won't be getting Siri AI anytime soon, if ever - and Apple wants them to blame the EU. Apple says its new AI-powered Siri will not launc…",
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/947051/apple-europe-dma-siri-ai',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/STK450_EU_G.jpg?quality=90&strip=all&crop=0%2C9.9676601489831%2C100%2C80.064679702034&w=1200',
#    'publishedAt': '2026-06-09T17:13:14Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nApple wants Europe to blink\r\nApple blames DMA for delaying Siri AI in Europe. The EU says nothing is stopping Apple from launching it. \r\nby\r\nRobert HartClose\r\nPo… [+7489 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Emma Roth',
#    'title': 'Apple is using AI to fix Safari’s extension problem',
#    'description': "Apple is trying to solve one of Safari's biggest weaknesses with AI. Safari has long lacked the robust library of extensions that its rivals have, mainly due to the stringent development requirements from Apple. But now, Apple is inviting users to essentially…",
#    'url': 'https://www.theverge.com/tech/946345/apple-safari-ai-update-extensions',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/describe-extension-safari.jpg?quality=90&strip=all&crop=0%2C10.742998834307%2C100%2C78.514002331385&w=1200',
#    'publishedAt': '2026-06-08T22:14:17Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSafari will invite users to vibe-code their own extensions.\r\nSafari will invite users to vibe-code their own extensions.\r\nby\r\nEmma RothClose\r\nPosts from this aut… [+4329 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Emma Roth',
#    'title': 'Apple WWDC 2026: The 7 biggest announcements',
#    'description': "Apple's keynote at this year's Worldwide Developers Conference was a big one. After months of delays, Apple reintroduced us to its AI-upgraded Siri, which will go beyond what the existing voice assistant can do by offering more personalized help. We also got …",
#    'url': 'https://www.theverge.com/tech/945693/apple-wwdc-2026-biggest-announcements-ios-27',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Screenshot-2026-06-08-at-1.01.41PM.png?quality=90&strip=all&crop=0%2C2.7453349442878%2C100%2C94.509330111424&w=1200',
#    'publishedAt': '2026-06-08T18:51:19Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe update-filled keynote showed an AI-upgraded Siri along with new features across Apples operating systems.\r\nby\r\nEmma RothClose\r\nPosts from this author will be… [+5329 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jennifer Pattison Tuohy',
#    'title': 'Apple, Google add support for Thread 1.4',
#    'description': 'Apple and Google are updating their smart home streaming devices to Thread 1.4. As first spotted by Matter Alpha and 9to5 Google, the latest spec has arrived on compatible Apple TVs in the tvOS 27 developer beta and the Google TV Streamer through a software u…',
#    'url': 'https://www.theverge.com/tech/947888/apple-google-add-support-for-thread-1-4',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/IMG_7137.jpg?quality=90&strip=all&crop=0%2C30.191972076789%2C100%2C69.808027923211&w=1200',
#    'publishedAt': '2026-06-10T20:30:33Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nIts almost time for one big Thread network!\r\nIts almost time for one big Thread network!\r\nby\r\nJennifer Pattison TuohyClose\r\nSenior Reviewer, Smart Home\r\nPosts fr… [+3614 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Janko Roettgers',
#    'title': 'Is Apple TV the new HBO?',
#    'description': 'This is Lowpass by Janko Roettgers, a newsletter on the ever-evolving intersection of tech and entertainment, syndicated just for The Verge subscribers once a week. Severance. Pachinko. Silo. Ted Lasso. Over the past couple of years, a number of Apple TV show…',
#    'url': 'https://www.theverge.com/column/948295/apple-tv-new-hbo',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/Severance_Photo_020912.jpg?quality=90&strip=all&crop=0%2C10.726247800535%2C100%2C78.54750439893&w=1200',
#    'publishedAt': '2026-06-11T12:19:25Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nUnlike competitors like Netflix, Apple TV emphasizes tentpole titles over large catalogs.\r\nUnlike competitors like Netflix, Apple TV emphasizes tentpole titles o… [+6523 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Antonio G. Di Benedetto',
#    'title': 'Apple announces macOS 27 Golden Gate',
#    'description': "Apple has announced macOS 27 Golden Gate, the next version of its desktop operating system. The new OS for MacBooks and Mac desktops is the follow-up to last year's macOS Tahoe 26. Tahoe added some handy features, like a revised Spotlight search and a Phone a…",
#    'url': 'https://www.theverge.com/tech/943695/apple-wwdc-2026-macos-27-macbook-mac-announcement-features',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/STK071_APPLE_D.webp?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T17:07:30Z',
#    'content': "Apple has announced macOS 27 Golden Gate, the next version of its desktop operating system.\nThe new OS for MacBooks and Mac desktops is the follow-up to last year's macOS Tahoe 26. Tahoe added some h… [+439 chars]"},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Stevie Bonifield',
#    'title': 'Apple announces visionOS 27 with Siri AI',
#    'description': "Along with new software for Macs and iPhones, Apple announced visionOS 27 during its keynote presentation at WWDC on Monday. Like its other platforms, visionOS 27 will feature Apple's updated Siri AI assistant and the new dedicated Siri app. You can use visua…",
#    'url': 'https://www.theverge.com/tech/944129/apple-visionos-updates-wwdc-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wwdc2026-visionos27.png?quality=90&strip=all&crop=0%2C9.6904971505351%2C100%2C80.61900569893&w=1200',
#    'publishedAt': '2026-06-08T18:32:00Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe latest version of Apples mixed reality OS debuts at WWDC.\r\nThe latest version of Apples mixed reality OS debuts at WWDC.\r\nby\r\nStevie BonifieldClose\r\nPosts fr… [+2266 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jess Weatherbed',
#    'title': 'Apple announces watchOS 27, now with Siri AI',
#    'description': 'Apple just announced watchOS 27, the next version of its Apple Watch operating system, introducing support for Siri AI, a redesigned "dynamic" app grid, and improvements to health and fitness tracking. The watchOS 27 update will be available "this fall," acco…',
#    'url': 'https://www.theverge.com/tech/943145/apple-watch-watchos-27-wwdc-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Apple-Watch-watchOS-27-Siri-AI.jpg?quality=90&strip=all&crop=0,14.033409967608,100,71.933180064785',
#    'publishedAt': '2026-06-08T19:34:10Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe upcoming update will be limited to Apples more recent Watch models.\r\nThe upcoming update will be limited to Apples more recent Watch models.\r\nby\r\nJess Weathe… [+4841 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sheena Vasani',
#    'title': 'The Apple Watch Series 11 is back to its best price',
#    'description': 'Apple’s upcoming watchOS 27 update will bring Siri AI and other exciting features to the Apple Watch Series 9 and newer Apple Watch models. If you’re contemplating an upgrade, all colorways of the GPS-enabled 42mm Apple Watch Series 11 — the latest model — ar…',
#    'url': 'https://www.theverge.com/gadgets/947773/apple-watch-series-11-beats-studio-buds-plus-deal-sale',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/12/Apple-Watch-Series-11-deal.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-10T14:57:20Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe slick Beats Studio Buds Plus are also on sale for just $100, and Fujifilms fun Instax Mini 12 is even cheaper.\r\nThe slick Beats Studio Buds Plus are also on … [+4447 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Victoria Song, Nilay Patel',
#    'title': 'WWDC 2026 bonus live blog: Tech Talk with Craig Federighi',
#    'description': 'Fresh off the WWDC keynote presentation, The Verge has been invited to an "on-the-record technical deep dive into the bold new architecture enabling Apple Intelligence capabilities." Apple SVP of Software Engineering Craig Federighi and his team will be there…',
#    'url': 'https://www.theverge.com/tech/946046/wwdc-2026-live-blog-tech-talk-with-craig-federighi',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wwdc-2026-the-verge-55_32.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T18:46:33Z',
#    'content': 'One of the funnier parts of the keynote.\r\n\n\nFresh off the WWDC keynote presentation, The Verge has been invited to an "on-the-record technical deep dive into the bold new architecture enabling Apple … [+915 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'WWDC protesters want Apple to ban Elon Musk’s apps',
#    'description': 'Apple\'s big developer conference is today, and protesters are using the occasion to call on the company to remove "nudify apps" from the App Store and pull "known" child sexual abuse material from iCloud. Outside the visitor\'s center at Apple\'s Cupertino camp…',
#    'url': 'https://www.theverge.com/tech/945813/apple-wwdc-protesters-deepfake-nude-apps-ultraviolet-heat-initiative',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/IMG_1699.jpg?quality=90&strip=all&crop=0%2C15.095986038394%2C100%2C69.808027923211&w=1200',
#    'publishedAt': '2026-06-08T16:37:09Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nTheyre also demanding a crackdown on child abuse imagery in iCloud.\r\nTheyre also demanding a crackdown on child abuse imagery in iCloud.\r\nby\r\nJay PetersClose\r\nPo… [+2186 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Stevie Bonifield',
#    'title': 'The App Store is going to add subscription bundles soon',
#    'description': "Later this year, you will be able to get bundled subscriptions for iPhone apps, as Apple announced it's expanding App Store bundles so they can include offers from different companies. It's similar to streaming video bundles that have combined offers for Appl…",
#    'url': 'https://www.theverge.com/tech/947365/apple-subscription-bundles-app-store',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/23925966/acastro_STK045_01.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-09T21:30:48Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nAlong with iOS 27, Apple also announced big changes to the App Store.\r\nAlong with iOS 27, Apple also announced big changes to the App Store.\r\nby\r\nStevie Bonifiel… [+2188 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Allison Johnson',
#    'title': 'Here comes new Siri again',
#    'description': 'Apple has been on its back foot, AI-wise, for the past few years. But in a strange way, playing from behind might not be such a bad move. At WWDC on Monday, Apple appears to be getting ready to reintroduce us to the new Siri. Again. As a reminder, we met the …',
#    'url': 'https://www.theverge.com/tech/944245/apple-wwdc-2026-ai-siri-gemini',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wwdc_2024.jpg?quality=90&strip=all&crop=0%2C10.597538331207%2C100%2C78.804923337586&w=1200',
#    'publishedAt': '2026-06-05T18:40:17Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nHere comes new Siri again\r\nIts time for a re-reintroduction.\r\nby\r\nAllison JohnsonClose\r\nPosts from this author will be added to your daily email digest and your … [+5969 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Stevie Bonifield',
#    'title': 'WWDC 2026: All the news from Apple’s developers conference',
#    'description': 'Apple’s annual WWDC event is kicking off on June 8th with a keynote presentation starting at 1PM ET / 10AM PT, where Apple will announce major updates to iOS, macOS, and its other operating systems.\xa0 Among those updates could be Apple’s delayed Siri overhaul,…',
#    'url': 'https://www.theverge.com/tech/944110/wwdc-2026-news-announcements',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/STK071_APPLE_E.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T16:05:33Z',
#    'content': 'Apples annual WWDC event is kicking off on June 8th with a keynote presentation starting at 1PM ET / 10AM PT, where Apple will announce major updates to iOS, macOS, and its other operating systems.\r\n… [+2748 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Stevie Bonifield',
#    'title': 'WWDC 2026: How to watch and what to expect',
#    'description': "Apple's biggest event of the year is nearly here. The company's Worldwide Developers Conference will spotlight updates to iOS, macOS, and all of Apple's other operating systems, and this year's event could also include a major overhaul for Siri. Here's how yo…",
#    'url': 'https://www.theverge.com/tech/944099/wwdc-2026-how-to-watch',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/unnamed-8.jpg?quality=90&strip=all&crop=0%2C18.517948191493%2C100%2C62.964103617014&w=1200',
#    'publishedAt': '2026-06-06T22:12:51Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nApples annual developer conference kicking off on June 8th could include a long-awaited Siri upgrade.\r\nApples annual developer conference kicking off on June 8th… [+3449 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'John.Higgins',
#    'title': 'Where was tvOS 27 at WWDC?',
#    'description': 'Every year, Apple\'s Worldwide Developers Conference gives us a first look at what\'s coming next to the company\'s many operating systems. But missing from today\'s keynote, apart from a single graphic listing all current Apple OSes next to a big "27," was any m…',
#    'url': 'https://www.theverge.com/tech/946329/tvos-27-absent-wwdc',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/22541100/DSCF3875_2.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T22:04:42Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nWith a focus on features instead of OS, tvOS 27 was only mentioned briefly in a quick presentation slide.\r\nWith a focus on features instead of OS, tvOS 27 was on… [+3594 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Lauren Feiner',
#    'title': 'Apple’s new parental controls are for keeping Apple out of trouble',
#    'description': "When Apple put child safety front and center at WWDC on Monday, its stated goal was helping parents fine-tune their kids' online experiences and avoid excessive screen time. But amid a global debate over internet regulation, its latest updates also looked lik…",
#    'url': 'https://www.theverge.com/policy/946331/apple-parental-controls-child-accounts-wwdc',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/02/STKS526_SOCIAL_MEDIA_TRIAL_CVIRGINIA_D.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-08T21:48:08Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nApple expanded its toolkit for parents at WWDC, but pushed developers to step up.\r\nApple expanded its toolkit for parents at WWDC, but pushed developers to step … [+6091 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew J. Hawkins',
#    'title': 'Jony Ive’s Ferrari looks nothing like a Ferrari',
#    'description': "Ferrari makes some of the fastest cars on the planet, so it's anyone's guess how the Italian automaker ended up being so incredibly late to the EV party. Long after most automakers have drastically scaled back their EV ambitions, cancelled battery-powered mod…",
#    'url': 'https://www.theverge.com/transportation/937077/ferrari-luce-ev-apple-car-jony-ive-design',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Luce_30rtv4_lightson_1x1hr_d955d06c-1be5-4001-99e2-55ce7e65f960_4a4d75.jpg?quality=90&strip=all&crop=0%2C22.665645835327%2C100%2C53.446325992659&w=1200',
#    'publishedAt': '2026-05-26T16:22:59Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nJony Ives Ferrari looks nothing like a Ferrari\r\nFerrari fans are losing it.\r\nby\r\nAndrew J. HawkinsClose\r\nPosts from this author will be added to your daily email… [+8773 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'Apple’s best AI idea looks a lot like vibe coding',
#    'description': "Most of Apple's current AI ideas are roughly the same as everyone else's AI ideas. A chatbot you can ask questions; quick ways to create or summarize text; bizarre, borderline creepy image-generation tools. The company spent most of its WWDC keynote playing c…",
#    'url': 'https://www.theverge.com/tech/946733/apple-shortcuts-ai-safari-tabs-vibe-code',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/AI-Apple-Shortcuts.jpg?quality=90&strip=all&crop=0%2C3.3555449785816%2C100%2C93.288910042837&w=1200',
#    'publishedAt': '2026-06-09T13:34:48Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nApples best AI idea looks a lot like vibe coding\r\nSiri AI and Image Playground will get all the hype, but Apple can actually make our lives better in Safari and … [+7449 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Richard Lawler',
#    'title': 'Apple’s accessibility features add more AI-powered processing',
#    'description': "Apple's annual update about accessibility features on its platforms has new additions for the iPhone, Mac, and especially Vision Pro, with a focus on how on-device AI processing is being used in features like VoiceOver, Magnifier, Voice Control, and Accessibi…",
#    'url': 'https://www.theverge.com/tech/933420/apple-iphone-mac-vision-pro-accessibility-2026-apple-intelligence',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Apple-accessibility-features-Magnifier.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-19T14:58:12Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nApples adding AI-generated subtitling for any video.\r\nApples adding AI-generated subtitling for any video.\r\nby\r\nRichard LawlerClose\r\nPosts from this author will … [+2739 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sean Hollister',
#    'title': 'Nvidia announces RTX Spark as ‘the most efficient PC chip ever built’',
#    'description': "This fall, Nvidia will officially become a consumer PC chipmaker like Intel, AMD, Apple, and Qualcomm, putting a complete computing chip - not just graphics - into the very heart of laptops and mini-PCs. After many months of leaks, it's finally announcing the…",
#    'url': 'https://www.theverge.com/tech/940589/nvidia-rtx-spark-n1-n1x-laptop-desktop-pc-cpu-gpu-ai-release-date',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/spark.jpg?quality=90&strip=all&crop=13.2,23.707517114377,86.8,58.222136995036',
#    'publishedAt': '2026-06-01T04:34:59Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nNvidia enters the consumer laptop realm.\r\nNvidia enters the consumer laptop realm.\r\nby\r\nSean HollisterClose\r\nPosts from this author will be added to your daily e… [+8779 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'Siri is good now??',
#    'description': 'You\'d be forgiven for thinking this day would never come. Siri has spent a decade and half somewhere between "sort of useful at a few things" and "utterly disastrous, why did I even try, can it honestly not even set a timer." But the wildest thing just happen…',
#    'url': 'https://www.theverge.com/podcast/949079/siri-ai-good-vergecast',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/VST_0612_Site.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-12T17:17:04Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nOn The Vergecast: Our first days with Siri AI, the next phase of social networks, and the Trump Phones a ripoff.\r\nOn The Vergecast: Our first days with Siri AI, … [+3128 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'Ugreen’s new soccer ball-shaped tracker has up to 7 years of battery life',
#    'description': 'Ugreen has announced a new Apple Find My-compatible tracker with a novel design that limits where you can hide it, but greatly benefits battery life. Inspired by "major football tournaments" the company doesn\'t call out by name, the Ugreen FineTrack 2 is shap…',
#    'url': 'https://www.theverge.com/tech/934101/ugreen-finetrack-2-mini-tracker-apple-find-my-soccer-ball',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/ugreen1.jpg?quality=90&strip=all&crop=0,10.732984293194,100,78.534031413613',
#    'publishedAt': '2026-05-19T19:49:11Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nBut when its non-replaceable battery finally dies, youll need to kick the FineTrack 2 into the e-waste bin.\r\nBut when its non-replaceable battery finally dies, y… [+2481 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Terrence O’Brien',
#    'title': 'Deezer launches an AI music detector for other streaming services',
#    'description': "Deezer will now scan your playlists on other streaming platforms to detect AI-generated music. Deezer was the first of the big streaming services to start labeling AI-generated music. It even offered its tech to other platforms, but it doesn't seem like it ha…",
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/948153/deezer-ai-music-detector-spotify-apple',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/NEW_1200-x-580-pixel-SI-logo-1240x600-1.jpeg?quality=90&strip=all&crop=3.7903225806452,0,92.41935483871,100',
#    'publishedAt': '2026-06-10T23:42:48Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSince the competition wont buy their tech, theyre bringing it directly to users.\r\nSince the competition wont buy their tech, theyre bringing it directly to users… [+2359 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Antonio G. Di Benedetto',
#    'title': 'My first 24 hours with Siri AI on the Mac',
#    'description': "I turned off Siri on the Mac years ago and never looked back. Similarly, I found Apple Intelligence so fruitless I never engage with it. But the new Siri AI coming to macOS 27 Golden Gate has at least got me slightly rethinking things. I'm still early in test…",
#    'url': 'https://www.theverge.com/tech/949502/apple-macos-27-golden-gate-siri-ai-apple-intelligence',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/061326_Siri_AI_MacBook_Pro_macOS_27_Golden_Gate_beta_ADiBenedetto_0003.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-13T13:44:07Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nMy first 24 hours with Siri AI on the Mac\r\nSiri is better, but its limitations are much more obvious on a Mac than an iPhone.\r\nby\r\nAntonio G. Di BenedettoClose\r\n… [+8253 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'John.Higgins',
#    'title': 'The three sets of earbuds I reach for',
#    'description': 'I have been an audio reviewer for 20 years. My time as a freelance headphones panelist at Wirecutter, and the multitude of reviews I’ve written for sites like Reviewed, Digital Trends, IGN, and now The Verge, have given me the chance to listen to hundreds of …',
#    'url': 'https://www.theverge.com/gadgets/947325/three-earbuds-i-consistently-use',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/268563_go-to_earbuds_JHiggins_0001.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-09T22:21:07Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nEarbuds come and go in the life of a reviewer, but these three have earned permanent spots in my life.\r\nIf you buy something from a Verge link, Vox Media may ear… [+8009 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': '5 things I already love from the iOS 27 beta',
#    'description': "iOS 27 has only been out for a few hours, and I've been messing around with the developer beta on my iPhone 16 Pro. I was most interested in trying out the new Siri AI, but unfortunately, I'm still on Apple's waitlist for that. In the meantime, I've been poki…",
#    'url': 'https://www.theverge.com/tech/946391/apple-ios-27-developer-beta-1-wwdc-2026-5-things',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/videoframe_560765.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2026-06-08T23:30:32Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nLike better icons and chonky widgets.\r\nLike better icons and chonky widgets.\r\nby\r\nJay PetersClose\r\nPosts from this author will be added to your daily email diges… [+3811 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Allison Johnson',
#    'title': 'I tried Siri AI, and so far it actually works',
#    'description': 'Parents want one thing, and one thing only, out of AI: to add a list of soccer games or "spirit week" theme days from an email or a poorly formatted flyer onto their calendar in one shot. And I have good news for parents with iPhones - the new Siri can finall…',
#    'url': 'https://www.theverge.com/tech/947432/siri-ai-apple-intelligence-ios-27-wwdc',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/DSC03775_processed.jpg?quality=90&strip=all&crop=0%2C10.723165084465%2C100%2C78.55366983107&w=1200',
#    'publishedAt': '2026-06-09T23:33:14Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nIts basic, but it works is a big deal.\r\nby\r\nAllison JohnsonClose\r\nPosts from this author will be added to your daily email digest and your homepage feed.\r\nFollow… [+5952 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'Apple’s new Siri AI knows when to shut up',
#    'description': "Apple's new Siri AI is finally here, and so far, it seems like it works. I have access and have been messing around with it, and my biggest impression so far is that Siri AI is quite curt - which I mean as a compliment. Many AI chatbots are cheery and wordy. …",
#    'url': 'https://www.theverge.com/tech/948155/apple-siri-ai-chatbot-personality',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/videoframe_13193.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2026-06-10T22:52:17Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSiri AI keeps things brief.\r\nSiri AI keeps things brief.\r\nby\r\nJay PetersClose\r\nPosts from this author will be added to your daily email digest and your homepage … [+5345 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'I have a new go-to browser',
#    'description': "Hi, friends! Welcome to Installer No. 129, your guide to the best and Verge-iest stuff in the world. (If you're new here, welcome, come on you Gunners, and also you can read all the old editions at the Installer homepage.) This week, I've mostly been sick, wh…",
#    'url': 'https://www.theverge.com/tech/936395/vivaldi-8-review-mandalorian-installer',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Installer-129.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-22T18:18:56Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nPlus, in this weeks Installer: The latest big thing from Star Wars, a couple of tech reads, and some Apple Shortcuts.\r\nPlus, in this weeks Installer: The latest … [+8654 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Brad Bourque',
#    'title': 'Motorola’s last-gen Razr Ultra is almost half off',
#    'description': 'Motorola’s latest Razr Ultra proves that its flip foldable format has evolved to become more than just a nostalgic gimmick. I’d understand if you’re not interested in shelling out $1,499.99 for the 2026 model, but the similar 2025 Motorola Razr Ultra with 512…',
#    'url': 'https://www.theverge.com/gadgets/938621/razr-ultra-roborock-qrevo-curv-2-robot-vacuum-deal-sale',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/moto-razr-2025-deal-image.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-28T18:33:08Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nPlus, a Roborock robot vacuum and mop we like is $100 off, and AirPods Max 2 are discounted.\r\nPlus, a Roborock robot vacuum and mop we like is $100 off, and AirP… [+3966 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Lauren Feiner',
#    'title': 'Microsoft could be the next Big Tech antitrust target',
#    'description': 'Over the past several years, Microsoft has largely managed to withstand populist calls to break up Big Tech while peers faced sweeping lawsuits. But a probe by the Federal Trade Commission suggests that grace period could be nearing an end. Earlier this year,…',
#    'url': 'https://www.theverge.com/policy/940220/microsoft-ftc-antitrust-investigation-cloud-ai',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/STKS530_FTC_Microsoft_AParkin3.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-01T13:23:39Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nAfter 25 years, an FTC investigation could put it back in the hot seat.\r\nAfter 25 years, an FTC investigation could put it back in the hot seat.\r\nby\r\nLauren Fein… [+9631 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sheena Vasani, Cameron Faulkner',
#    'title': 'The best Memorial Day sales you can shop this weekend',
#    'description': 'Memorial Day is nearly here, meaning the seasonal sales are in full swing. If your weekend plans involve pool parties or barbecues, now is a great time to pick up a portable speaker or set of solar lights, as many of our favorite models are currently on sale.…',
#    'url': 'https://www.theverge.com/gadgets/936196/best-memorial-day-sales-tech-deals-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/09/257943_Airpods_Pro3_AKrales_0103.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-22T16:50:38Z',
#    'content': 'Memorial Day is nearly here, meaning the seasonal sales are in full swing. If your weekend plans involve pool parties or barbecues, now is a great time to pick up a portable speaker or set of solar l… [+30889 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'The new Halide camera app launches with film looks and an upgraded photo editor',
#    'description': "After first being announced in December 2024, Lux Optics has finally released the latest version of its Halide camera app for the iPhone and iPad. The Halide Mark III app's most compelling feature is a new film simulation engine and a collection of five new L…",
#    'url': 'https://www.theverge.com/tech/938339/lux-optics-halide-mark-iii-ios-iphone-camera-app-looks-editor-raw-files-now-available',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/halidecamera1.jpg?quality=90&strip=all&crop=0%2C10.765679560227%2C100%2C78.468640879546&w=1200',
#    'publishedAt': '2026-05-27T20:06:12Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nHalide Mark III includes five unique looks and an upgraded photo editor that can process RAW files from other cameras.\r\nHalide Mark III includes five unique look… [+3511 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sheena Vasani',
#    'title': 'Apple’s latest MacBook Air is $200 off in both sizes for Memorial Day',
#    'description': 'If you’re looking for a laptop that’ll still perform well several years from now, Apple’s latest MacBook Air is hard to beat. Now, in particular, is a good time to pick one up, as you can currently buy the 13-inch MacBook Air at Amazon in the run-up to Memori…',
#    'url': 'https://www.theverge.com/gadgets/936610/apple-macbook-air-m5-memorial-day-2026-deal-sale',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/268408_Apple_MacBook_Air_15_M5_laptop_ADiBenedetto_0026.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-24T14:56:48Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe M5 Air is fast enough for everyday tasks and then some, which is why its our top laptop rec for most people.\r\nThe M5 Air is fast enough for everyday tasks an… [+3042 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'The post-search Google era begins',
#    'description': "Google is many things, but most of the time it's a verb: It is what it is to search the internet for information. But what if it's an AI agent doing the searching? And it's doing it proactively? Without even telling you about it? In the world Google imagines,…",
#    'url': 'https://www.theverge.com/podcast/936037/google-io-2026-search-agents-vergecast',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/VRG_VST_0522_Site.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-22T13:47:41Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nOn The Vergecast: The AI will Google for you now, the Trump Phone is real, and SpaceX is SpaceT-Mobile.\r\nOn The Vergecast: The AI will Google for you now, the Tr… [+3113 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'Sennheiser’s new Momentum 5 headphones have upgraded ANC and a replaceable battery',
#    'description': "Nearly four years after the last version of Sennheiser's Momentum headphones debuted with a redesign that traded a retro aesthetic for a more contemporary and comfortable design, the company has announced its Momentum 5 Wireless headphones. They look very sim…",
#    'url': 'https://www.theverge.com/tech/936127/sennheiser-momentum-5-wireless-headphones-anc-lossless-bluetooth',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/sennheiser1.jpg?quality=90&strip=all&crop=0%2C10.740836125969%2C100%2C78.518327748063&w=1200',
#    'publishedAt': '2026-05-22T16:29:51Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nDouble the microphones means better noise canceling and call quality.\r\nDouble the microphones means better noise canceling and call quality.\r\nby\r\nAndrew Liszewsk… [+3305 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jacob Kastrenakes',
#    'title': 'We react to Google I/O 2026',
#    'description': "What better way to unwind from a two-hour-long keynote presentation than to pour over the weirdest and wildest details, from a Gmail bot you can converse with to DeepMind's leader saying the singularity is near. The Vergecast went live right after the show, w…",
#    'url': 'https://www.theverge.com/podcast/934202/we-react-to-google-i-o-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/20260519_VCthumb_v2.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2026-05-19T21:48:26Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nby\r\nJacob KastrenakesClose\r\nPosts from this author will be added to your daily email digest and your homepage feed.\r\nFollow\r\nFollowSee All by Jacob Kastrenakes\r\n… [+3047 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sheena Vasani',
#    'title': 'Here are our favorite Memorial Day tech deals so far',
#    'description': 'Memorial Day marks the unofficial start of summer, and the holiday’s sales include plenty of deals on gadgets that can help you make the most of the season. If your plans involve beach days, pool parties, or backyard barbecues, now’s a great time to pick up a…',
#    'url': 'https://www.theverge.com/gadgets/932465/best-memorial-day-sales-deals-2026',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/jbl_charge6_flip7_1.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-19T20:25:09Z',
#    'content': 'Portable bluetooth speakers like the Charge 6 and Flip 7 are just a few on sale for Memorial Day.\r\n\n\nMemorial Day marks the unofficial start of summer, and the holiday’s sales include plenty of deals… [+25369 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Dominic Preston',
#    'title': 'User-replaceable batteries are coming back in a big way',
#    'description': "This is The Stepback, a weekly newsletter breaking down one essential story from the tech world. For more news about gadgets and smartphones, follow Dominic Preston. The Stepback arrives in our subscribers' inboxes at 8AM ET. Opt in for The Stepback here. How…",
#    'url': 'https://www.theverge.com/column/939026/user-replaceable-batteries-eu-european-union-legislation',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/24647291/236644_Fairbuds_XL_JPorter_0012.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-29T12:32:55Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethics statement.\r\nby\r\nDominic PrestonClose\r\nPosts from this author will be adde… [+13922 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Robert Hart',
#    'title': 'Tech companies desperately want to film you doing chores',
#    'description': "This week, an AI training startup called Shift said it would clean New Yorkers' homes for free. It has plans to expand into other cities as well, including London, and looking around my flat, I get the appeal. But there's a catch. There's always a catch. In e…",
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/940007/ai-companies-will-pay-for-robot-training-data',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/STK414_AI_CVIRGINIA_I__0009_7.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-29T17:37:43Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nStartups are paying people for the real-world data needed to train their robots. \r\nStartups are paying people for the real-world data needed to train their robot… [+5060 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Allison Johnson',
#    'title': 'Vibe coding is coming to your phone',
#    'description': '"There\'s an app for that" was the promise of the App Store from the very beginning. The app that will get your phone to do the thing you want it to? It\'s just a few taps away. The tagline wasn\'t strictly true - I\'m still waiting for that one perfect grocery l…',
#    'url': 'https://www.theverge.com/tech/934628/google-io-2026-android-ai-studio-widgets-shortcuts',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/10/258002_Google_Pixel_10_Pro_Fold_AJohnson_0010.jpg?quality=90&strip=all&crop=0%2C10.723165084465%2C100%2C78.55366983107&w=1200',
#    'publishedAt': '2026-05-20T17:37:21Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nPersonal tech is about to get a lot more personal.\r\nPersonal tech is about to get a lot more personal.\r\nby\r\nAllison JohnsonClose\r\nPosts from this author will be … [+5291 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'TC. Sottek',
#    'title': 'As AI gets better, it reveals an empty promise',
#    'description': "This week we've got tandem hands-ons with Google's new Gemini AI agent - Spark - from my colleagues David Pierce and Jay Peters. Their takeaways are similar: It's so effective that it's scary. Spark knew that David's dog is named Frida and knew the first name…",
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/942629/as-ai-gets-better-it-reveals-an-empty-promise',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/11503853/mdoying_180419_1777_0454_2.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-03T17:47:27Z',
#    'content': '<ul><li></li></ul>\r\nYour new assistant can schedule a meeting but it cant fix our broken world.\r\nYour new assistant can schedule a meeting but it cant fix our broken world.\r\nby\r\nTC SottekClose\r\nPosts… [+5443 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'John.Higgins',
#    'title': 'WiiM expands its whole-home ecosystem with a new soundbar',
#    'description': "WiiM, the audio company that's challenged the idea that audiophile-level performance requires a small loan, is expanding its whole-home ecosystem with the WiiM Bar, which releases in July. Much like its other speakers and audio components, the WiiM Bar suppor…",
#    'url': 'https://www.theverge.com/tech/942748/wiim-releases-first-soundbar',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wiim-bar-lifestyle.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-03T21:12:51Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe company is known for making high-quality, inexpensive audio products, and the WiiM Bar is its first home theater speaker.\r\nThe company is known for making hi… [+3635 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Terrence O’Brien',
#    'title': 'Feeble Little Horse leans into digital weirdness on bitknot',
#    'description': "From the opening moments of bitknot, it's obvious that Feeble Little Horse has found an entirely new gear. Where on Girl with Fish the blown-out textures were more '90s indie rock and shoegaze, on their latest LP, there's a more modern edge to the distortion …",
#    'url': 'https://www.theverge.com/entertainment/940449/feeble-little-horse-bitknot-music-album-review',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Feeble-Little-Horse-bitknot.jpg?quality=90&strip=all&crop=5.4333333333333%2C0%2C89.133333333333%2C100&w=1200',
#    'publishedAt': '2026-05-30T18:11:18Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe band has evolved from exciting indie rock throwback into something more cutting-edge.\r\nThe band has evolved from exciting indie rock throwback into something… [+4314 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'Boox’s quirky page-turning remote won me over',
#    'description': 'Following the launch of the surprisingly popular Kobo Remote, Boox has released its own device to ease the burden of reaching for an e-reader’s touchscreen that’s an arm’s length away. The Tappy isn’t Boox’s first page-turning remote, but its design takes a m…',
#    'url': 'https://www.theverge.com/tech/943699/slug-boox-tappy-wireless-bluetooth-remote-page-turn-android-ios-hands-on',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/booxtappy7.jpg?quality=90&strip=all&crop=0%2C10.740836125969%2C100%2C78.518327748063&w=1200',
#    'publishedAt': '2026-06-10T14:15:18Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nUnlike the Kobo Remote, Booxs Tappy also works with iPhones, Android devices, and other e-readers.\r\nUnlike the Kobo Remote, Booxs Tappy also works with iPhones, … [+6170 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Victoria Song',
#    'title': '‘Solve all diseases,’ you say?',
#    'description': "This is Optimizer, a weekly newsletter sent from Verge senior reviewer Victoria Song that dissects and discusses the latest gizmos and potions that swear they're going to change your life. This week's issue is a special early edition tied to The Verge's Googl…",
#    'url': 'https://www.theverge.com/column/935021/google-io-gemini-for-science-alphafold-alphagenome-ai-health',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/demishassabis.webp?quality=90&strip=all&crop=0%2C10.597538331207%2C100%2C78.804923337586&w=1200',
#    'publishedAt': '2026-05-20T21:06:35Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nGoogle DeepMind CEO Demis Hassabis made a bold claim at this years I/O keynote. Not so fast!\r\nby\r\nVictoria SongClose\r\nSenior Reviewer, Wearable Tech\r\nPosts from … [+9375 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Lauren Feiner',
#    'title': 'America’s dangerous, messy deepfakes crackdown is here',
#    'description': 'A law requiring social networks to quickly remove sexual deepfakes and other nonconsensual imagery is now fully in force. But experts warn the policy could do little to help victims - and at worst could facilitate censorship online. Last May, President Donald…',
#    'url': 'https://www.theverge.com/policy/933518/take-it-down-act-notice-removal-social-media-deepfake',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/STK419_DEEPFAKE_3_CVIRGINIA_C.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-19T14:58:19Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe Take It Down Act is in full force, but it could be a gift to government censors not victims of image-based sexual abuse.\r\nThe Take It Down Act is in full for… [+7991 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Thomas Ricker',
#    'title': 'Solid-state batteries still aren’t ready, but gels are',
#    'description': "This is The Stepback, a weekly newsletter breaking down one essential story from the tech world. For more on e-bikes, power stations, and how to work anywhere, follow Thomas Ricker. The Stepback arrives in our subscribers' inboxes at 8AM ET. Opt in for The St…",
#    'url': 'https://www.theverge.com/column/948594/solid-state-batteries-semi-solid-state',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/268587_Stepback_solid_state__CVirginia.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-06-14T05:48:21Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSemi-solid state batteries are a less volatile bridge to the future.\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethics sta… [+8750 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Antonio G. Di Benedetto',
#    'title': 'If I could only have one laptop for work and gaming, I’d get this one',
#    'description': "I've loved the Asus ROG Zephyrus G14 since it launched in 2020. I bought one for my wife after reading about how awesome it was on a little site called The Verge dot com. Since then, the G14 has gotten some facelifts, chip bumps, an occasional special edition…",
#    'url': 'https://www.theverge.com/tech/935898/asus-rog-zephyrus-g14-2026-intel-nvidia-review',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/268552_Asus_ROG_Zephyrus_G14_2026_Intel_ADiBenedetto_0012.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-22T13:01:59Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nThe new Asus ROG Zephyrus G14 is almost perfect for me, except its $3,600.\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethi… [+15012 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sean Hollister',
#    'title': '‘Fuck you, Bambu’: How one private message could change the face of 3D printing',
#    'description': 'Bambu Lab makes the best, most accessible 3D printers yet, but that reputation is suddenly under siege. It all started when Paweł Jarczak received a private message from the company on Reddit asking him to delete his code. Now the 3D printing community is lin…',
#    'url': 'https://www.theverge.com/tech/931532/bambu-agpl-pawel-jarczak-open-source-threat-dmca-github',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/11/bambu_lab1.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2026-05-20T22:02:02Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nFuck you, Bambu: How one private message could change the face of 3D printing\r\nBambu was set to become the Apple of 3D printers. Then it DMd the wrong person.\r\nb… [+19057 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'The next YouTube phenomenon hitting the big screen',
#    'description': "Hi, friends! Welcome to Installer No. 131, your guide to the best and Verge-iest stuff in the world. (If you're new here, welcome, happy last week of productivity before the World Cup starts, and also you can read all the old editions at the Installer homepag…",
#    'url': 'https://www.theverge.com/tech/944942/amazing-digital-circus-lego-pokemon-installer',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Verge-Tools-Installer.png?quality=90&strip=all&crop=0%2C10.788682187813%2C100%2C78.422635624373&w=1200',
#    'publishedAt': '2026-06-06T02:13:05Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nPlus, in this weeks Installer: More ways to play Final Fantasy, an awesome set of smart Legos, and much more.\r\nPlus, in this weeks Installer: More ways to play F… [+11921 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Nilay Patel',
#    'title': 'Rivian’s software chief thinks you don’t need CarPlay or buttons',
#    'description': 'Today, I’m talking with Wassym Bensaid, the chief software officer at Rivian, and the co-CEO of Rivian’s platform joint venture with Volkswagen, which everyone just calls RV Tech. That joint venture kicked off about a year and a half ago with a nearly $6 bill…',
#    'url': 'https://www.theverge.com/podcast/929940/rivian-wassym-bensaid-software-volkswagen-carplay-assistant-ai',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/DCD-Wassym-Bensaid.png?quality=90&strip=all&crop=0%2C10.711631919237%2C100%2C78.576736161526&w=1200',
#    'publishedAt': '2026-05-28T14:03:31Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nWassym Bensaid on why AI-powered voice control should be the future interface of car software.\r\nby\r\nNilay PatelClose\r\nPosts from this author will be added to you… [+55367 chars]'}]}

# %%
articles = data['articles']
type(articles)
articles
# Out:
# [{'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Louryn Strampe',
#   'title': 'Memorial Day Tech Deals: Sony, Apple, Beats (2026)',
#   'description': 'Lots of our most-recommended headphones, power banks, and other gadgets are on sale for Memorial Day.',
#   'url': 'https://www.wired.com/story/memorial-day-tech-deals-2026-1/',
#   'urlToImage': 'https://media.wired.com/photos/6a06188db84b146a9eec38c1/191:100/w_1280,c_limit/Memorial%20Day%20Deals%20Tech%20top%20art%20052026%20SOURCE%20Amazon.jpg',
#   'publishedAt': '2026-05-22T18:52:47Z',
#   'content': "When you think of Memorial Day sales, you probably think of mattresses and other home goods. And while those items are definitely discounted, now is also a good time to purchase tech. Personally, I'm… [+1064 chars]"},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Luke Larsen',
#   'title': 'MacOS 27 Golden Gate: Top New Features',
#   'description': "Apple has announced the latest version of macOS. It's all about the reintroduction of Siri, which is now accessible from anywhere on the Mac desktop.",
#   'url': 'https://www.wired.com/story/macos-27-golden-gate-top-features/',
#   'urlToImage': 'https://media.wired.com/photos/6a2849c20d6aa02c6a8cdf9e/191:100/w_1280,c_limit/Apple-OS-27-updates-260608.jpg',
#   'publishedAt': '2026-06-09T17:33:21Z',
#   'content': 'One of the most interesting new features is Custom Extensions, which lets you create an extension for Safari in natural language. Lastly, the new version of Safari will work the Passwords app to auto… [+2328 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Julian Chokkattu',
#   'title': 'Apple’s iPhone Camera App Is Getting an AI Upgrade in iOS 27',
#   'description': 'Siri is now directly embedded into the camera app, and there are more artificial intelligence tools in the Photos app to alter your images.',
#   'url': 'https://www.wired.com/story/apples-iphone-camera-app-is-getting-an-ai-upgrade-in-ios-27/',
#   'urlToImage': 'https://media.wired.com/photos/6a270a0e623237895b48f975/191:100/w_1280,c_limit/apple-camera-app-gear-2233007119.jpg',
#   'publishedAt': '2026-06-08T18:40:32Z',
#   'content': 'Your iPhone camera app will look a little different this fall. On Monday at its annual Worldwide Developers Conference in Cupertino, California, Apple showed off new features in its next version of i… [+2335 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Boutayna Chokrane',
#   'title': '2 Best Bluetooth Trackers of 2026, Plus Honorable Mentions',
#   'description': 'Constantly losing your stuff? Here are the best Bluetooth trackers to help you keep everything in check—plus some guidance on staying safe while using them.',
#   'url': 'https://www.wired.com/story/the-best-bluetooth-trackers/',
#   'urlToImage': 'https://media.wired.com/photos/6a232b2b713a46b95a632884/191:100/w_1280,c_limit/The-Best-Bluetooth-Trackers.jpg',
#   'publishedAt': '2026-06-06T10:38:00Z',
#   'content': "I'd like to believe I'm organized. Reality suggests otherwise. I've left my smartphone in the refrigerator and spent hours searching for it. I've misplaced my AirPods and Oura Ring for days at a time… [+2518 chars]"},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Luke Larsen',
#   'title': 'I Never Liked a Laptop Sleeve Until I Tried the Bellroy Laptop Caddy',
#   'description': "The Bellroy Laptop Caddy is actually so much more than a laptop sleeve. With all the extra space and pockets, it's the best laptop companion I've ever used.",
#   'url': 'https://www.wired.com/story/finally-a-laptop-sleeve-for-me/',
#   'urlToImage': 'https://media.wired.com/photos/6a0cabd72c7ee96598e09971/191:100/w_1280,c_limit/Bellroy%20Laptop%20Caddy%20SOURCE%20Bellroy%20(Bag%20Check).jpg',
#   'publishedAt': '2026-05-26T09:32:00Z',
#   'content': 'As we get out of the house, the gear-obsessed WIRED Reviews team is writing about our favorite bags and EDCs. Today, reviewer Luke Larsenraves about his love for his Bellroy Laptop Caddy. You can als… [+2204 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Paresh Dave, Lauren Goode, Zoë Schiffer',
#   'title': 'Meta Employees Are Scrambling to Use Up Benefits Ahead of Layoffs',
#   'description': 'On the eve of about 8,000 jobs being cut, employees are cashing in on headphone stipends and other perks while they still can.',
#   'url': 'https://www.wired.com/story/meta-employees-scramble-benefits-layoffs-ai/',
#   'urlToImage': 'https://media.wired.com/photos/6a0cb2b791b600abc11af14d/191:100/w_1280,c_limit/Meta-Employees-Scrambling-to-Use-Up-Benefits-Ahead-of-Layoffs-Business-2272777092.jpg',
#   'publishedAt': '2026-05-19T19:00:46Z',
#   'content': 'Ahead of Metas latest round of mass layoffs tomorrow, some employees are deserting offices, abandoning their work, and loading up on perks they might soon lose, several people at the company tell WIR… [+2885 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jennifer Pattison Tuohy',
#   'title': 'Cameras get an Apple Intelligence boost in Apple Home',
#   'description': 'Apple Intelligence is coming to cameras connected to Apple Home. At WWDC, Apple announced that with iOS27, the Home app will use Apple Intelligence to analyze footage and generate descriptions summarizing what the camera saw. You can also search footage with …',
#   'url': 'https://www.theverge.com/tech/946032/apple-home-ai-camera-descriptions-search-4k',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Screenshot-2026-06-08-at-1.58.57PM.png?quality=90&strip=all&crop=0%2C3.5746394385138%2C100%2C92.850721122972&w=1200',
#   'publishedAt': '2026-06-08T18:50:04Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nSecurity cameras connected to the Home app can use AI to search footage, and HomeKit Secure Video will finally support 4K resolution.\r\nSecurity cameras connected… [+2622 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jay Peters',
#   'title': 'Apple announces iOS 27',
#   'description': 'Apple announced its next major iOS update, iOS 27, at WWDC 2026 on Monday. Apple is highlighting performance and design improvements as a major feature, and the update will be supported all the way back to the iPhone 11. A big change is an opacity slider for …',
#   'url': 'https://www.theverge.com/tech/941202/apple-ios-27-wwdc-2026',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/STK071_APPLE_E.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-08T17:23:57Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nYour iPhone is getting new features.\r\nYour iPhone is getting new features.\r\nby\r\nJay PetersClose\r\nPosts from this author will be added to your daily email digest … [+2895 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Andrew Liszewski',
#   'title': 'Apple announces iPadOS 27',
#   'description': "Today at Apple's Worldwide Developers Conference, the company announced new features coming to the iPad with iPadOS 27 including optimizations such as apps launching up to 30 percent faster by intelligently preloading needed info, and more responsive switchin…",
#   'url': 'https://www.theverge.com/tech/942546/apple-ipados-27-wwdc-2026',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/ipados1.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-08T17:51:14Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nThe iPads next big update is expected to arrive later this year.\r\nThe iPads next big update is expected to arrive later this year.\r\nby\r\nAndrew LiszewskiClose\r\nPo… [+3864 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Robert Hart',
#   'title': 'Apple wants Europe to blink',
#   'description': "It took a few years, but Apple finally made its AI look useful. Now millions of iPhone users in Europe are being told they won't be getting Siri AI anytime soon, if ever - and Apple wants them to blame the EU. Apple says its new AI-powered Siri will not launc…",
#   'url': 'https://www.theverge.com/ai-artificial-intelligence/947051/apple-europe-dma-siri-ai',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/STK450_EU_G.jpg?quality=90&strip=all&crop=0%2C9.9676601489831%2C100%2C80.064679702034&w=1200',
#   'publishedAt': '2026-06-09T17:13:14Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nApple wants Europe to blink\r\nApple blames DMA for delaying Siri AI in Europe. The EU says nothing is stopping Apple from launching it. \r\nby\r\nRobert HartClose\r\nPo… [+7489 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Emma Roth',
#   'title': 'Apple is using AI to fix Safari’s extension problem',
#   'description': "Apple is trying to solve one of Safari's biggest weaknesses with AI. Safari has long lacked the robust library of extensions that its rivals have, mainly due to the stringent development requirements from Apple. But now, Apple is inviting users to essentially…",
#   'url': 'https://www.theverge.com/tech/946345/apple-safari-ai-update-extensions',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/describe-extension-safari.jpg?quality=90&strip=all&crop=0%2C10.742998834307%2C100%2C78.514002331385&w=1200',
#   'publishedAt': '2026-06-08T22:14:17Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nSafari will invite users to vibe-code their own extensions.\r\nSafari will invite users to vibe-code their own extensions.\r\nby\r\nEmma RothClose\r\nPosts from this aut… [+4329 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Emma Roth',
#   'title': 'Apple WWDC 2026: The 7 biggest announcements',
#   'description': "Apple's keynote at this year's Worldwide Developers Conference was a big one. After months of delays, Apple reintroduced us to its AI-upgraded Siri, which will go beyond what the existing voice assistant can do by offering more personalized help. We also got …",
#   'url': 'https://www.theverge.com/tech/945693/apple-wwdc-2026-biggest-announcements-ios-27',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Screenshot-2026-06-08-at-1.01.41PM.png?quality=90&strip=all&crop=0%2C2.7453349442878%2C100%2C94.509330111424&w=1200',
#   'publishedAt': '2026-06-08T18:51:19Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nThe update-filled keynote showed an AI-upgraded Siri along with new features across Apples operating systems.\r\nby\r\nEmma RothClose\r\nPosts from this author will be… [+5329 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jennifer Pattison Tuohy',
#   'title': 'Apple, Google add support for Thread 1.4',
#   'description': 'Apple and Google are updating their smart home streaming devices to Thread 1.4. As first spotted by Matter Alpha and 9to5 Google, the latest spec has arrived on compatible Apple TVs in the tvOS 27 developer beta and the Google TV Streamer through a software u…',
#   'url': 'https://www.theverge.com/tech/947888/apple-google-add-support-for-thread-1-4',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/IMG_7137.jpg?quality=90&strip=all&crop=0%2C30.191972076789%2C100%2C69.808027923211&w=1200',
#   'publishedAt': '2026-06-10T20:30:33Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nIts almost time for one big Thread network!\r\nIts almost time for one big Thread network!\r\nby\r\nJennifer Pattison TuohyClose\r\nSenior Reviewer, Smart Home\r\nPosts fr… [+3614 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Janko Roettgers',
#   'title': 'Is Apple TV the new HBO?',
#   'description': 'This is Lowpass by Janko Roettgers, a newsletter on the ever-evolving intersection of tech and entertainment, syndicated just for The Verge subscribers once a week. Severance. Pachinko. Silo. Ted Lasso. Over the past couple of years, a number of Apple TV show…',
#   'url': 'https://www.theverge.com/column/948295/apple-tv-new-hbo',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/Severance_Photo_020912.jpg?quality=90&strip=all&crop=0%2C10.726247800535%2C100%2C78.54750439893&w=1200',
#   'publishedAt': '2026-06-11T12:19:25Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nUnlike competitors like Netflix, Apple TV emphasizes tentpole titles over large catalogs.\r\nUnlike competitors like Netflix, Apple TV emphasizes tentpole titles o… [+6523 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Antonio G. Di Benedetto',
#   'title': 'Apple announces macOS 27 Golden Gate',
#   'description': "Apple has announced macOS 27 Golden Gate, the next version of its desktop operating system. The new OS for MacBooks and Mac desktops is the follow-up to last year's macOS Tahoe 26. Tahoe added some handy features, like a revised Spotlight search and a Phone a…",
#   'url': 'https://www.theverge.com/tech/943695/apple-wwdc-2026-macos-27-macbook-mac-announcement-features',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/STK071_APPLE_D.webp?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-08T17:07:30Z',
#   'content': "Apple has announced macOS 27 Golden Gate, the next version of its desktop operating system.\nThe new OS for MacBooks and Mac desktops is the follow-up to last year's macOS Tahoe 26. Tahoe added some h… [+439 chars]"},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Stevie Bonifield',
#   'title': 'Apple announces visionOS 27 with Siri AI',
#   'description': "Along with new software for Macs and iPhones, Apple announced visionOS 27 during its keynote presentation at WWDC on Monday. Like its other platforms, visionOS 27 will feature Apple's updated Siri AI assistant and the new dedicated Siri app. You can use visua…",
#   'url': 'https://www.theverge.com/tech/944129/apple-visionos-updates-wwdc-2026',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wwdc2026-visionos27.png?quality=90&strip=all&crop=0%2C9.6904971505351%2C100%2C80.61900569893&w=1200',
#   'publishedAt': '2026-06-08T18:32:00Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nThe latest version of Apples mixed reality OS debuts at WWDC.\r\nThe latest version of Apples mixed reality OS debuts at WWDC.\r\nby\r\nStevie BonifieldClose\r\nPosts fr… [+2266 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jess Weatherbed',
#   'title': 'Apple announces watchOS 27, now with Siri AI',
#   'description': 'Apple just announced watchOS 27, the next version of its Apple Watch operating system, introducing support for Siri AI, a redesigned "dynamic" app grid, and improvements to health and fitness tracking. The watchOS 27 update will be available "this fall," acco…',
#   'url': 'https://www.theverge.com/tech/943145/apple-watch-watchos-27-wwdc-2026',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Apple-Watch-watchOS-27-Siri-AI.jpg?quality=90&strip=all&crop=0,14.033409967608,100,71.933180064785',
#   'publishedAt': '2026-06-08T19:34:10Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nThe upcoming update will be limited to Apples more recent Watch models.\r\nThe upcoming update will be limited to Apples more recent Watch models.\r\nby\r\nJess Weathe… [+4841 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Sheena Vasani',
#   'title': 'The Apple Watch Series 11 is back to its best price',
#   'description': 'Apple’s upcoming watchOS 27 update will bring Siri AI and other exciting features to the Apple Watch Series 9 and newer Apple Watch models. If you’re contemplating an upgrade, all colorways of the GPS-enabled 42mm Apple Watch Series 11 — the latest model — ar…',
#   'url': 'https://www.theverge.com/gadgets/947773/apple-watch-series-11-beats-studio-buds-plus-deal-sale',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/12/Apple-Watch-Series-11-deal.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-10T14:57:20Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nThe slick Beats Studio Buds Plus are also on sale for just $100, and Fujifilms fun Instax Mini 12 is even cheaper.\r\nThe slick Beats Studio Buds Plus are also on … [+4447 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Victoria Song, Nilay Patel',
#   'title': 'WWDC 2026 bonus live blog: Tech Talk with Craig Federighi',
#   'description': 'Fresh off the WWDC keynote presentation, The Verge has been invited to an "on-the-record technical deep dive into the bold new architecture enabling Apple Intelligence capabilities." Apple SVP of Software Engineering Craig Federighi and his team will be there…',
#   'url': 'https://www.theverge.com/tech/946046/wwdc-2026-live-blog-tech-talk-with-craig-federighi',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wwdc-2026-the-verge-55_32.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-08T18:46:33Z',
#   'content': 'One of the funnier parts of the keynote.\r\n\n\nFresh off the WWDC keynote presentation, The Verge has been invited to an "on-the-record technical deep dive into the bold new architecture enabling Apple … [+915 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jay Peters',
#   'title': 'WWDC protesters want Apple to ban Elon Musk’s apps',
#   'description': 'Apple\'s big developer conference is today, and protesters are using the occasion to call on the company to remove "nudify apps" from the App Store and pull "known" child sexual abuse material from iCloud. Outside the visitor\'s center at Apple\'s Cupertino camp…',
#   'url': 'https://www.theverge.com/tech/945813/apple-wwdc-protesters-deepfake-nude-apps-ultraviolet-heat-initiative',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/IMG_1699.jpg?quality=90&strip=all&crop=0%2C15.095986038394%2C100%2C69.808027923211&w=1200',
#   'publishedAt': '2026-06-08T16:37:09Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nTheyre also demanding a crackdown on child abuse imagery in iCloud.\r\nTheyre also demanding a crackdown on child abuse imagery in iCloud.\r\nby\r\nJay PetersClose\r\nPo… [+2186 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Stevie Bonifield',
#   'title': 'The App Store is going to add subscription bundles soon',
#   'description': "Later this year, you will be able to get bundled subscriptions for iPhone apps, as Apple announced it's expanding App Store bundles so they can include offers from different companies. It's similar to streaming video bundles that have combined offers for Appl…",
#   'url': 'https://www.theverge.com/tech/947365/apple-subscription-bundles-app-store',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/23925966/acastro_STK045_01.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-09T21:30:48Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nAlong with iOS 27, Apple also announced big changes to the App Store.\r\nAlong with iOS 27, Apple also announced big changes to the App Store.\r\nby\r\nStevie Bonifiel… [+2188 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Allison Johnson',
#   'title': 'Here comes new Siri again',
#   'description': 'Apple has been on its back foot, AI-wise, for the past few years. But in a strange way, playing from behind might not be such a bad move. At WWDC on Monday, Apple appears to be getting ready to reintroduce us to the new Siri. Again. As a reminder, we met the …',
#   'url': 'https://www.theverge.com/tech/944245/apple-wwdc-2026-ai-siri-gemini',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wwdc_2024.jpg?quality=90&strip=all&crop=0%2C10.597538331207%2C100%2C78.804923337586&w=1200',
#   'publishedAt': '2026-06-05T18:40:17Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nHere comes new Siri again\r\nIts time for a re-reintroduction.\r\nby\r\nAllison JohnsonClose\r\nPosts from this author will be added to your daily email digest and your … [+5969 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Stevie Bonifield',
#   'title': 'WWDC 2026: All the news from Apple’s developers conference',
#   'description': 'Apple’s annual WWDC event is kicking off on June 8th with a keynote presentation starting at 1PM ET / 10AM PT, where Apple will announce major updates to iOS, macOS, and its other operating systems.\xa0 Among those updates could be Apple’s delayed Siri overhaul,…',
#   'url': 'https://www.theverge.com/tech/944110/wwdc-2026-news-announcements',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/STK071_APPLE_E.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-08T16:05:33Z',
#   'content': 'Apples annual WWDC event is kicking off on June 8th with a keynote presentation starting at 1PM ET / 10AM PT, where Apple will announce major updates to iOS, macOS, and its other operating systems.\r\n… [+2748 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Stevie Bonifield',
#   'title': 'WWDC 2026: How to watch and what to expect',
#   'description': "Apple's biggest event of the year is nearly here. The company's Worldwide Developers Conference will spotlight updates to iOS, macOS, and all of Apple's other operating systems, and this year's event could also include a major overhaul for Siri. Here's how yo…",
#   'url': 'https://www.theverge.com/tech/944099/wwdc-2026-how-to-watch',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/unnamed-8.jpg?quality=90&strip=all&crop=0%2C18.517948191493%2C100%2C62.964103617014&w=1200',
#   'publishedAt': '2026-06-06T22:12:51Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nApples annual developer conference kicking off on June 8th could include a long-awaited Siri upgrade.\r\nApples annual developer conference kicking off on June 8th… [+3449 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'John.Higgins',
#   'title': 'Where was tvOS 27 at WWDC?',
#   'description': 'Every year, Apple\'s Worldwide Developers Conference gives us a first look at what\'s coming next to the company\'s many operating systems. But missing from today\'s keynote, apart from a single graphic listing all current Apple OSes next to a big "27," was any m…',
#   'url': 'https://www.theverge.com/tech/946329/tvos-27-absent-wwdc',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/22541100/DSCF3875_2.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-08T22:04:42Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nWith a focus on features instead of OS, tvOS 27 was only mentioned briefly in a quick presentation slide.\r\nWith a focus on features instead of OS, tvOS 27 was on… [+3594 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Lauren Feiner',
#   'title': 'Apple’s new parental controls are for keeping Apple out of trouble',
#   'description': "When Apple put child safety front and center at WWDC on Monday, its stated goal was helping parents fine-tune their kids' online experiences and avoid excessive screen time. But amid a global debate over internet regulation, its latest updates also looked lik…",
#   'url': 'https://www.theverge.com/policy/946331/apple-parental-controls-child-accounts-wwdc',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/02/STKS526_SOCIAL_MEDIA_TRIAL_CVIRGINIA_D.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-08T21:48:08Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nApple expanded its toolkit for parents at WWDC, but pushed developers to step up.\r\nApple expanded its toolkit for parents at WWDC, but pushed developers to step … [+6091 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Andrew J. Hawkins',
#   'title': 'Jony Ive’s Ferrari looks nothing like a Ferrari',
#   'description': "Ferrari makes some of the fastest cars on the planet, so it's anyone's guess how the Italian automaker ended up being so incredibly late to the EV party. Long after most automakers have drastically scaled back their EV ambitions, cancelled battery-powered mod…",
#   'url': 'https://www.theverge.com/transportation/937077/ferrari-luce-ev-apple-car-jony-ive-design',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Luce_30rtv4_lightson_1x1hr_d955d06c-1be5-4001-99e2-55ce7e65f960_4a4d75.jpg?quality=90&strip=all&crop=0%2C22.665645835327%2C100%2C53.446325992659&w=1200',
#   'publishedAt': '2026-05-26T16:22:59Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nJony Ives Ferrari looks nothing like a Ferrari\r\nFerrari fans are losing it.\r\nby\r\nAndrew J. HawkinsClose\r\nPosts from this author will be added to your daily email… [+8773 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'David Pierce',
#   'title': 'Apple’s best AI idea looks a lot like vibe coding',
#   'description': "Most of Apple's current AI ideas are roughly the same as everyone else's AI ideas. A chatbot you can ask questions; quick ways to create or summarize text; bizarre, borderline creepy image-generation tools. The company spent most of its WWDC keynote playing c…",
#   'url': 'https://www.theverge.com/tech/946733/apple-shortcuts-ai-safari-tabs-vibe-code',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/AI-Apple-Shortcuts.jpg?quality=90&strip=all&crop=0%2C3.3555449785816%2C100%2C93.288910042837&w=1200',
#   'publishedAt': '2026-06-09T13:34:48Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nApples best AI idea looks a lot like vibe coding\r\nSiri AI and Image Playground will get all the hype, but Apple can actually make our lives better in Safari and … [+7449 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Richard Lawler',
#   'title': 'Apple’s accessibility features add more AI-powered processing',
#   'description': "Apple's annual update about accessibility features on its platforms has new additions for the iPhone, Mac, and especially Vision Pro, with a focus on how on-device AI processing is being used in features like VoiceOver, Magnifier, Voice Control, and Accessibi…",
#   'url': 'https://www.theverge.com/tech/933420/apple-iphone-mac-vision-pro-accessibility-2026-apple-intelligence',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Apple-accessibility-features-Magnifier.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-19T14:58:12Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nApples adding AI-generated subtitling for any video.\r\nApples adding AI-generated subtitling for any video.\r\nby\r\nRichard LawlerClose\r\nPosts from this author will … [+2739 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Sean Hollister',
#   'title': 'Nvidia announces RTX Spark as ‘the most efficient PC chip ever built’',
#   'description': "This fall, Nvidia will officially become a consumer PC chipmaker like Intel, AMD, Apple, and Qualcomm, putting a complete computing chip - not just graphics - into the very heart of laptops and mini-PCs. After many months of leaks, it's finally announcing the…",
#   'url': 'https://www.theverge.com/tech/940589/nvidia-rtx-spark-n1-n1x-laptop-desktop-pc-cpu-gpu-ai-release-date',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/spark.jpg?quality=90&strip=all&crop=13.2,23.707517114377,86.8,58.222136995036',
#   'publishedAt': '2026-06-01T04:34:59Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nNvidia enters the consumer laptop realm.\r\nNvidia enters the consumer laptop realm.\r\nby\r\nSean HollisterClose\r\nPosts from this author will be added to your daily e… [+8779 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'David Pierce',
#   'title': 'Siri is good now??',
#   'description': 'You\'d be forgiven for thinking this day would never come. Siri has spent a decade and half somewhere between "sort of useful at a few things" and "utterly disastrous, why did I even try, can it honestly not even set a timer." But the wildest thing just happen…',
#   'url': 'https://www.theverge.com/podcast/949079/siri-ai-good-vergecast',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/VST_0612_Site.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-12T17:17:04Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nOn The Vergecast: Our first days with Siri AI, the next phase of social networks, and the Trump Phones a ripoff.\r\nOn The Vergecast: Our first days with Siri AI, … [+3128 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Andrew Liszewski',
#   'title': 'Ugreen’s new soccer ball-shaped tracker has up to 7 years of battery life',
#   'description': 'Ugreen has announced a new Apple Find My-compatible tracker with a novel design that limits where you can hide it, but greatly benefits battery life. Inspired by "major football tournaments" the company doesn\'t call out by name, the Ugreen FineTrack 2 is shap…',
#   'url': 'https://www.theverge.com/tech/934101/ugreen-finetrack-2-mini-tracker-apple-find-my-soccer-ball',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/ugreen1.jpg?quality=90&strip=all&crop=0,10.732984293194,100,78.534031413613',
#   'publishedAt': '2026-05-19T19:49:11Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nBut when its non-replaceable battery finally dies, youll need to kick the FineTrack 2 into the e-waste bin.\r\nBut when its non-replaceable battery finally dies, y… [+2481 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Terrence O’Brien',
#   'title': 'Deezer launches an AI music detector for other streaming services',
#   'description': "Deezer will now scan your playlists on other streaming platforms to detect AI-generated music. Deezer was the first of the big streaming services to start labeling AI-generated music. It even offered its tech to other platforms, but it doesn't seem like it ha…",
#   'url': 'https://www.theverge.com/ai-artificial-intelligence/948153/deezer-ai-music-detector-spotify-apple',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/NEW_1200-x-580-pixel-SI-logo-1240x600-1.jpeg?quality=90&strip=all&crop=3.7903225806452,0,92.41935483871,100',
#   'publishedAt': '2026-06-10T23:42:48Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nSince the competition wont buy their tech, theyre bringing it directly to users.\r\nSince the competition wont buy their tech, theyre bringing it directly to users… [+2359 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Antonio G. Di Benedetto',
#   'title': 'My first 24 hours with Siri AI on the Mac',
#   'description': "I turned off Siri on the Mac years ago and never looked back. Similarly, I found Apple Intelligence so fruitless I never engage with it. But the new Siri AI coming to macOS 27 Golden Gate has at least got me slightly rethinking things. I'm still early in test…",
#   'url': 'https://www.theverge.com/tech/949502/apple-macos-27-golden-gate-siri-ai-apple-intelligence',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/061326_Siri_AI_MacBook_Pro_macOS_27_Golden_Gate_beta_ADiBenedetto_0003.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-13T13:44:07Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nMy first 24 hours with Siri AI on the Mac\r\nSiri is better, but its limitations are much more obvious on a Mac than an iPhone.\r\nby\r\nAntonio G. Di BenedettoClose\r\n… [+8253 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'John.Higgins',
#   'title': 'The three sets of earbuds I reach for',
#   'description': 'I have been an audio reviewer for 20 years. My time as a freelance headphones panelist at Wirecutter, and the multitude of reviews I’ve written for sites like Reviewed, Digital Trends, IGN, and now The Verge, have given me the chance to listen to hundreds of …',
#   'url': 'https://www.theverge.com/gadgets/947325/three-earbuds-i-consistently-use',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/268563_go-to_earbuds_JHiggins_0001.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-09T22:21:07Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nEarbuds come and go in the life of a reviewer, but these three have earned permanent spots in my life.\r\nIf you buy something from a Verge link, Vox Media may ear… [+8009 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jay Peters',
#   'title': '5 things I already love from the iOS 27 beta',
#   'description': "iOS 27 has only been out for a few hours, and I've been messing around with the developer beta on my iPhone 16 Pro. I was most interested in trying out the new Siri AI, but unfortunately, I'm still on Apple's waitlist for that. In the meantime, I've been poki…",
#   'url': 'https://www.theverge.com/tech/946391/apple-ios-27-developer-beta-1-wwdc-2026-5-things',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/videoframe_560765.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#   'publishedAt': '2026-06-08T23:30:32Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nLike better icons and chonky widgets.\r\nLike better icons and chonky widgets.\r\nby\r\nJay PetersClose\r\nPosts from this author will be added to your daily email diges… [+3811 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Allison Johnson',
#   'title': 'I tried Siri AI, and so far it actually works',
#   'description': 'Parents want one thing, and one thing only, out of AI: to add a list of soccer games or "spirit week" theme days from an email or a poorly formatted flyer onto their calendar in one shot. And I have good news for parents with iPhones - the new Siri can finall…',
#   'url': 'https://www.theverge.com/tech/947432/siri-ai-apple-intelligence-ios-27-wwdc',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/DSC03775_processed.jpg?quality=90&strip=all&crop=0%2C10.723165084465%2C100%2C78.55366983107&w=1200',
#   'publishedAt': '2026-06-09T23:33:14Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nIts basic, but it works is a big deal.\r\nby\r\nAllison JohnsonClose\r\nPosts from this author will be added to your daily email digest and your homepage feed.\r\nFollow… [+5952 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jay Peters',
#   'title': 'Apple’s new Siri AI knows when to shut up',
#   'description': "Apple's new Siri AI is finally here, and so far, it seems like it works. I have access and have been messing around with it, and my biggest impression so far is that Siri AI is quite curt - which I mean as a compliment. Many AI chatbots are cheery and wordy. …",
#   'url': 'https://www.theverge.com/tech/948155/apple-siri-ai-chatbot-personality',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/videoframe_13193.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#   'publishedAt': '2026-06-10T22:52:17Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nSiri AI keeps things brief.\r\nSiri AI keeps things brief.\r\nby\r\nJay PetersClose\r\nPosts from this author will be added to your daily email digest and your homepage … [+5345 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'David Pierce',
#   'title': 'I have a new go-to browser',
#   'description': "Hi, friends! Welcome to Installer No. 129, your guide to the best and Verge-iest stuff in the world. (If you're new here, welcome, come on you Gunners, and also you can read all the old editions at the Installer homepage.) This week, I've mostly been sick, wh…",
#   'url': 'https://www.theverge.com/tech/936395/vivaldi-8-review-mandalorian-installer',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Installer-129.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-22T18:18:56Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nPlus, in this weeks Installer: The latest big thing from Star Wars, a couple of tech reads, and some Apple Shortcuts.\r\nPlus, in this weeks Installer: The latest … [+8654 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Brad Bourque',
#   'title': 'Motorola’s last-gen Razr Ultra is almost half off',
#   'description': 'Motorola’s latest Razr Ultra proves that its flip foldable format has evolved to become more than just a nostalgic gimmick. I’d understand if you’re not interested in shelling out $1,499.99 for the 2026 model, but the similar 2025 Motorola Razr Ultra with 512…',
#   'url': 'https://www.theverge.com/gadgets/938621/razr-ultra-roborock-qrevo-curv-2-robot-vacuum-deal-sale',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/moto-razr-2025-deal-image.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-28T18:33:08Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nPlus, a Roborock robot vacuum and mop we like is $100 off, and AirPods Max 2 are discounted.\r\nPlus, a Roborock robot vacuum and mop we like is $100 off, and AirP… [+3966 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Lauren Feiner',
#   'title': 'Microsoft could be the next Big Tech antitrust target',
#   'description': 'Over the past several years, Microsoft has largely managed to withstand populist calls to break up Big Tech while peers faced sweeping lawsuits. But a probe by the Federal Trade Commission suggests that grace period could be nearing an end. Earlier this year,…',
#   'url': 'https://www.theverge.com/policy/940220/microsoft-ftc-antitrust-investigation-cloud-ai',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/STKS530_FTC_Microsoft_AParkin3.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-01T13:23:39Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nAfter 25 years, an FTC investigation could put it back in the hot seat.\r\nAfter 25 years, an FTC investigation could put it back in the hot seat.\r\nby\r\nLauren Fein… [+9631 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Sheena Vasani, Cameron Faulkner',
#   'title': 'The best Memorial Day sales you can shop this weekend',
#   'description': 'Memorial Day is nearly here, meaning the seasonal sales are in full swing. If your weekend plans involve pool parties or barbecues, now is a great time to pick up a portable speaker or set of solar lights, as many of our favorite models are currently on sale.…',
#   'url': 'https://www.theverge.com/gadgets/936196/best-memorial-day-sales-tech-deals-2026',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/09/257943_Airpods_Pro3_AKrales_0103.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-22T16:50:38Z',
#   'content': 'Memorial Day is nearly here, meaning the seasonal sales are in full swing. If your weekend plans involve pool parties or barbecues, now is a great time to pick up a portable speaker or set of solar l… [+30889 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Andrew Liszewski',
#   'title': 'The new Halide camera app launches with film looks and an upgraded photo editor',
#   'description': "After first being announced in December 2024, Lux Optics has finally released the latest version of its Halide camera app for the iPhone and iPad. The Halide Mark III app's most compelling feature is a new film simulation engine and a collection of five new L…",
#   'url': 'https://www.theverge.com/tech/938339/lux-optics-halide-mark-iii-ios-iphone-camera-app-looks-editor-raw-files-now-available',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/halidecamera1.jpg?quality=90&strip=all&crop=0%2C10.765679560227%2C100%2C78.468640879546&w=1200',
#   'publishedAt': '2026-05-27T20:06:12Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nHalide Mark III includes five unique looks and an upgraded photo editor that can process RAW files from other cameras.\r\nHalide Mark III includes five unique look… [+3511 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Sheena Vasani',
#   'title': 'Apple’s latest MacBook Air is $200 off in both sizes for Memorial Day',
#   'description': 'If you’re looking for a laptop that’ll still perform well several years from now, Apple’s latest MacBook Air is hard to beat. Now, in particular, is a good time to pick one up, as you can currently buy the 13-inch MacBook Air at Amazon in the run-up to Memori…',
#   'url': 'https://www.theverge.com/gadgets/936610/apple-macbook-air-m5-memorial-day-2026-deal-sale',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/268408_Apple_MacBook_Air_15_M5_laptop_ADiBenedetto_0026.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-24T14:56:48Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nThe M5 Air is fast enough for everyday tasks and then some, which is why its our top laptop rec for most people.\r\nThe M5 Air is fast enough for everyday tasks an… [+3042 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'David Pierce',
#   'title': 'The post-search Google era begins',
#   'description': "Google is many things, but most of the time it's a verb: It is what it is to search the internet for information. But what if it's an AI agent doing the searching? And it's doing it proactively? Without even telling you about it? In the world Google imagines,…",
#   'url': 'https://www.theverge.com/podcast/936037/google-io-2026-search-agents-vergecast',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/VRG_VST_0522_Site.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-22T13:47:41Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nOn The Vergecast: The AI will Google for you now, the Trump Phone is real, and SpaceX is SpaceT-Mobile.\r\nOn The Vergecast: The AI will Google for you now, the Tr… [+3113 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Andrew Liszewski',
#   'title': 'Sennheiser’s new Momentum 5 headphones have upgraded ANC and a replaceable battery',
#   'description': "Nearly four years after the last version of Sennheiser's Momentum headphones debuted with a redesign that traded a retro aesthetic for a more contemporary and comfortable design, the company has announced its Momentum 5 Wireless headphones. They look very sim…",
#   'url': 'https://www.theverge.com/tech/936127/sennheiser-momentum-5-wireless-headphones-anc-lossless-bluetooth',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/sennheiser1.jpg?quality=90&strip=all&crop=0%2C10.740836125969%2C100%2C78.518327748063&w=1200',
#   'publishedAt': '2026-05-22T16:29:51Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nDouble the microphones means better noise canceling and call quality.\r\nDouble the microphones means better noise canceling and call quality.\r\nby\r\nAndrew Liszewsk… [+3305 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jacob Kastrenakes',
#   'title': 'We react to Google I/O 2026',
#   'description': "What better way to unwind from a two-hour-long keynote presentation than to pour over the weirdest and wildest details, from a Gmail bot you can converse with to DeepMind's leader saying the singularity is near. The Vergecast went live right after the show, w…",
#   'url': 'https://www.theverge.com/podcast/934202/we-react-to-google-i-o-2026',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/20260519_VCthumb_v2.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#   'publishedAt': '2026-05-19T21:48:26Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nby\r\nJacob KastrenakesClose\r\nPosts from this author will be added to your daily email digest and your homepage feed.\r\nFollow\r\nFollowSee All by Jacob Kastrenakes\r\n… [+3047 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Sheena Vasani',
#   'title': 'Here are our favorite Memorial Day tech deals so far',
#   'description': 'Memorial Day marks the unofficial start of summer, and the holiday’s sales include plenty of deals on gadgets that can help you make the most of the season. If your plans involve beach days, pool parties, or backyard barbecues, now’s a great time to pick up a…',
#   'url': 'https://www.theverge.com/gadgets/932465/best-memorial-day-sales-deals-2026',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/jbl_charge6_flip7_1.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-19T20:25:09Z',
#   'content': 'Portable bluetooth speakers like the Charge 6 and Flip 7 are just a few on sale for Memorial Day.\r\n\n\nMemorial Day marks the unofficial start of summer, and the holiday’s sales include plenty of deals… [+25369 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Dominic Preston',
#   'title': 'User-replaceable batteries are coming back in a big way',
#   'description': "This is The Stepback, a weekly newsletter breaking down one essential story from the tech world. For more news about gadgets and smartphones, follow Dominic Preston. The Stepback arrives in our subscribers' inboxes at 8AM ET. Opt in for The Stepback here. How…",
#   'url': 'https://www.theverge.com/column/939026/user-replaceable-batteries-eu-european-union-legislation',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/24647291/236644_Fairbuds_XL_JPorter_0012.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-29T12:32:55Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethics statement.\r\nby\r\nDominic PrestonClose\r\nPosts from this author will be adde… [+13922 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Robert Hart',
#   'title': 'Tech companies desperately want to film you doing chores',
#   'description': "This week, an AI training startup called Shift said it would clean New Yorkers' homes for free. It has plans to expand into other cities as well, including London, and looking around my flat, I get the appeal. But there's a catch. There's always a catch. In e…",
#   'url': 'https://www.theverge.com/ai-artificial-intelligence/940007/ai-companies-will-pay-for-robot-training-data',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/STK414_AI_CVIRGINIA_I__0009_7.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-29T17:37:43Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nStartups are paying people for the real-world data needed to train their robots. \r\nStartups are paying people for the real-world data needed to train their robot… [+5060 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Allison Johnson',
#   'title': 'Vibe coding is coming to your phone',
#   'description': '"There\'s an app for that" was the promise of the App Store from the very beginning. The app that will get your phone to do the thing you want it to? It\'s just a few taps away. The tagline wasn\'t strictly true - I\'m still waiting for that one perfect grocery l…',
#   'url': 'https://www.theverge.com/tech/934628/google-io-2026-android-ai-studio-widgets-shortcuts',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/10/258002_Google_Pixel_10_Pro_Fold_AJohnson_0010.jpg?quality=90&strip=all&crop=0%2C10.723165084465%2C100%2C78.55366983107&w=1200',
#   'publishedAt': '2026-05-20T17:37:21Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nPersonal tech is about to get a lot more personal.\r\nPersonal tech is about to get a lot more personal.\r\nby\r\nAllison JohnsonClose\r\nPosts from this author will be … [+5291 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'TC. Sottek',
#   'title': 'As AI gets better, it reveals an empty promise',
#   'description': "This week we've got tandem hands-ons with Google's new Gemini AI agent - Spark - from my colleagues David Pierce and Jay Peters. Their takeaways are similar: It's so effective that it's scary. Spark knew that David's dog is named Frida and knew the first name…",
#   'url': 'https://www.theverge.com/ai-artificial-intelligence/942629/as-ai-gets-better-it-reveals-an-empty-promise',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/11503853/mdoying_180419_1777_0454_2.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-03T17:47:27Z',
#   'content': '<ul><li></li></ul>\r\nYour new assistant can schedule a meeting but it cant fix our broken world.\r\nYour new assistant can schedule a meeting but it cant fix our broken world.\r\nby\r\nTC SottekClose\r\nPosts… [+5443 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'John.Higgins',
#   'title': 'WiiM expands its whole-home ecosystem with a new soundbar',
#   'description': "WiiM, the audio company that's challenged the idea that audiophile-level performance requires a small loan, is expanding its whole-home ecosystem with the WiiM Bar, which releases in July. Much like its other speakers and audio components, the WiiM Bar suppor…",
#   'url': 'https://www.theverge.com/tech/942748/wiim-releases-first-soundbar',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/wiim-bar-lifestyle.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-03T21:12:51Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nThe company is known for making high-quality, inexpensive audio products, and the WiiM Bar is its first home theater speaker.\r\nThe company is known for making hi… [+3635 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Terrence O’Brien',
#   'title': 'Feeble Little Horse leans into digital weirdness on bitknot',
#   'description': "From the opening moments of bitknot, it's obvious that Feeble Little Horse has found an entirely new gear. Where on Girl with Fish the blown-out textures were more '90s indie rock and shoegaze, on their latest LP, there's a more modern edge to the distortion …",
#   'url': 'https://www.theverge.com/entertainment/940449/feeble-little-horse-bitknot-music-album-review',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/Feeble-Little-Horse-bitknot.jpg?quality=90&strip=all&crop=5.4333333333333%2C0%2C89.133333333333%2C100&w=1200',
#   'publishedAt': '2026-05-30T18:11:18Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nThe band has evolved from exciting indie rock throwback into something more cutting-edge.\r\nThe band has evolved from exciting indie rock throwback into something… [+4314 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Andrew Liszewski',
#   'title': 'Boox’s quirky page-turning remote won me over',
#   'description': 'Following the launch of the surprisingly popular Kobo Remote, Boox has released its own device to ease the burden of reaching for an e-reader’s touchscreen that’s an arm’s length away. The Tappy isn’t Boox’s first page-turning remote, but its design takes a m…',
#   'url': 'https://www.theverge.com/tech/943699/slug-boox-tappy-wireless-bluetooth-remote-page-turn-android-ios-hands-on',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/booxtappy7.jpg?quality=90&strip=all&crop=0%2C10.740836125969%2C100%2C78.518327748063&w=1200',
#   'publishedAt': '2026-06-10T14:15:18Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nUnlike the Kobo Remote, Booxs Tappy also works with iPhones, Android devices, and other e-readers.\r\nUnlike the Kobo Remote, Booxs Tappy also works with iPhones, … [+6170 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Victoria Song',
#   'title': '‘Solve all diseases,’ you say?',
#   'description': "This is Optimizer, a weekly newsletter sent from Verge senior reviewer Victoria Song that dissects and discusses the latest gizmos and potions that swear they're going to change your life. This week's issue is a special early edition tied to The Verge's Googl…",
#   'url': 'https://www.theverge.com/column/935021/google-io-gemini-for-science-alphafold-alphagenome-ai-health',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/demishassabis.webp?quality=90&strip=all&crop=0%2C10.597538331207%2C100%2C78.804923337586&w=1200',
#   'publishedAt': '2026-05-20T21:06:35Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nGoogle DeepMind CEO Demis Hassabis made a bold claim at this years I/O keynote. Not so fast!\r\nby\r\nVictoria SongClose\r\nSenior Reviewer, Wearable Tech\r\nPosts from … [+9375 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Lauren Feiner',
#   'title': 'America’s dangerous, messy deepfakes crackdown is here',
#   'description': 'A law requiring social networks to quickly remove sexual deepfakes and other nonconsensual imagery is now fully in force. But experts warn the policy could do little to help victims - and at worst could facilitate censorship online. Last May, President Donald…',
#   'url': 'https://www.theverge.com/policy/933518/take-it-down-act-notice-removal-social-media-deepfake',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/03/STK419_DEEPFAKE_3_CVIRGINIA_C.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-19T14:58:19Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nThe Take It Down Act is in full force, but it could be a gift to government censors not victims of image-based sexual abuse.\r\nThe Take It Down Act is in full for… [+7991 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Thomas Ricker',
#   'title': 'Solid-state batteries still aren’t ready, but gels are',
#   'description': "This is The Stepback, a weekly newsletter breaking down one essential story from the tech world. For more on e-bikes, power stations, and how to work anywhere, follow Thomas Ricker. The Stepback arrives in our subscribers' inboxes at 8AM ET. Opt in for The St…",
#   'url': 'https://www.theverge.com/column/948594/solid-state-batteries-semi-solid-state',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/268587_Stepback_solid_state__CVirginia.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-06-14T05:48:21Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nSemi-solid state batteries are a less volatile bridge to the future.\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethics sta… [+8750 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Antonio G. Di Benedetto',
#   'title': 'If I could only have one laptop for work and gaming, I’d get this one',
#   'description': "I've loved the Asus ROG Zephyrus G14 since it launched in 2020. I bought one for my wife after reading about how awesome it was on a little site called The Verge dot com. Since then, the G14 has gotten some facelifts, chip bumps, an occasional special edition…",
#   'url': 'https://www.theverge.com/tech/935898/asus-rog-zephyrus-g14-2026-intel-nvidia-review',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/268552_Asus_ROG_Zephyrus_G14_2026_Intel_ADiBenedetto_0012.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-22T13:01:59Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nThe new Asus ROG Zephyrus G14 is almost perfect for me, except its $3,600.\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethi… [+15012 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Sean Hollister',
#   'title': '‘Fuck you, Bambu’: How one private message could change the face of 3D printing',
#   'description': 'Bambu Lab makes the best, most accessible 3D printers yet, but that reputation is suddenly under siege. It all started when Paweł Jarczak received a private message from the company on Reddit asking him to delete his code. Now the 3D printing community is lin…',
#   'url': 'https://www.theverge.com/tech/931532/bambu-agpl-pawel-jarczak-open-source-threat-dmca-github',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/11/bambu_lab1.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2026-05-20T22:02:02Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nFuck you, Bambu: How one private message could change the face of 3D printing\r\nBambu was set to become the Apple of 3D printers. Then it DMd the wrong person.\r\nb… [+19057 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'David Pierce',
#   'title': 'The next YouTube phenomenon hitting the big screen',
#   'description': "Hi, friends! Welcome to Installer No. 131, your guide to the best and Verge-iest stuff in the world. (If you're new here, welcome, happy last week of productivity before the World Cup starts, and also you can read all the old editions at the Installer homepag…",
#   'url': 'https://www.theverge.com/tech/944942/amazing-digital-circus-lego-pokemon-installer',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/Verge-Tools-Installer.png?quality=90&strip=all&crop=0%2C10.788682187813%2C100%2C78.422635624373&w=1200',
#   'publishedAt': '2026-06-06T02:13:05Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nPlus, in this weeks Installer: More ways to play Final Fantasy, an awesome set of smart Legos, and much more.\r\nPlus, in this weeks Installer: More ways to play F… [+11921 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Nilay Patel',
#   'title': 'Rivian’s software chief thinks you don’t need CarPlay or buttons',
#   'description': 'Today, I’m talking with Wassym Bensaid, the chief software officer at Rivian, and the co-CEO of Rivian’s platform joint venture with Volkswagen, which everyone just calls RV Tech. That joint venture kicked off about a year and a half ago with a nearly $6 bill…',
#   'url': 'https://www.theverge.com/podcast/929940/rivian-wassym-bensaid-software-volkswagen-carplay-assistant-ai',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/05/DCD-Wassym-Bensaid.png?quality=90&strip=all&crop=0%2C10.711631919237%2C100%2C78.576736161526&w=1200',
#   'publishedAt': '2026-05-28T14:03:31Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nWassym Bensaid on why AI-powered voice control should be the future interface of car software.\r\nby\r\nNilay PatelClose\r\nPosts from this author will be added to you… [+55367 chars]'}]

# %%
articles_df = pd.DataFrame(articles)
articles_df.head()
# Out:
#                              source             author  \
# 0  {'id': 'wired', 'name': 'Wired'}     Louryn Strampe
# 1  {'id': 'wired', 'name': 'Wired'}        Luke Larsen
# 2  {'id': 'wired', 'name': 'Wired'}   Julian Chokkattu
# 3  {'id': 'wired', 'name': 'Wired'}  Boutayna Chokrane
# 4  {'id': 'wired', 'name': 'Wired'}        Luke Larsen
#
#                                                title  \
# 0  Memorial Day Tech Deals: Sony, Apple, Beats (2...
# 1             MacOS 27 Golden Gate: Top New Features
# 2  Apple’s iPhone Camera App Is Getting an AI Upg...
# 3  2 Best Bluetooth Trackers of 2026, Plus Honora...
# 4  I Never Liked a Laptop Sleeve Until I Tried th...
#
#                                          description  \
# 0  Lots of our most-recommended headphones, power...
# 1  Apple has announced the latest version of macO...
# 2  Siri is now directly embedded into the camera ...
# 3  Constantly losing your stuff? Here are the bes...
# 4  The Bellroy Laptop Caddy is actually so much m...
#
#                                                  url  \
# 0  https://www.wired.com/story/memorial-day-tech-...
# 1  https://www.wired.com/story/macos-27-golden-ga...
# 2  https://www.wired.com/story/apples-iphone-came...
# 3  https://www.wired.com/story/the-best-bluetooth...
# 4  https://www.wired.com/story/finally-a-laptop-s...
#
#                                           urlToImage           publishedAt  \
# 0  https://media.wired.com/photos/6a06188db84b146...  2026-05-22T18:52:47Z
# 1  https://media.wired.com/photos/6a2849c20d6aa02...  2026-06-09T17:33:21Z
# 2  https://media.wired.com/photos/6a270a0e6232378...  2026-06-08T18:40:32Z
# 3  https://media.wired.com/photos/6a232b2b713a46b...  2026-06-06T10:38:00Z
# 4  https://media.wired.com/photos/6a0cabd72c7ee96...  2026-05-26T09:32:00Z
#
#                                              content
# 0  When you think of Memorial Day sales, you prob...
# 1  One of the most interesting new features is Cu...
# 2  Your iPhone camera app will look a little diff...
# 3  I'd like to believe I'm organized. Reality sug...
# 4  As we get out of the house, the gear-obsessed ...

# %%
# drop column source

articles_df = articles_df.drop(columns={'source', 'urlToImage'})
articles_df.head()
# Out:
#               author                                              title  \
# 0     Louryn Strampe  Memorial Day Tech Deals: Sony, Apple, Beats (2...
# 1        Luke Larsen             MacOS 27 Golden Gate: Top New Features
# 2   Julian Chokkattu  Apple’s iPhone Camera App Is Getting an AI Upg...
# 3  Boutayna Chokrane  2 Best Bluetooth Trackers of 2026, Plus Honora...
# 4        Luke Larsen  I Never Liked a Laptop Sleeve Until I Tried th...
#
#                                          description  \
# 0  Lots of our most-recommended headphones, power...
# 1  Apple has announced the latest version of macO...
# 2  Siri is now directly embedded into the camera ...
# 3  Constantly losing your stuff? Here are the bes...
# 4  The Bellroy Laptop Caddy is actually so much m...
#
#                                                  url           publishedAt  \
# 0  https://www.wired.com/story/memorial-day-tech-...  2026-05-22T18:52:47Z
# 1  https://www.wired.com/story/macos-27-golden-ga...  2026-06-09T17:33:21Z
# 2  https://www.wired.com/story/apples-iphone-came...  2026-06-08T18:40:32Z
# 3  https://www.wired.com/story/the-best-bluetooth...  2026-06-06T10:38:00Z
# 4  https://www.wired.com/story/finally-a-laptop-s...  2026-05-26T09:32:00Z
#
#                                              content
# 0  When you think of Memorial Day sales, you prob...
# 1  One of the most interesting new features is Cu...
# 2  Your iPhone camera app will look a little diff...
# 3  I'd like to believe I'm organized. Reality sug...
# 4  As we get out of the house, the gear-obsessed ...

# %%
# store to db

DB_HOST = os.getenv('DB_HOST')
DB_PORT = os.getenv('DB_PORT')
DB_NAME = os.getenv('DB_NAME')
DB_USER = os.getenv('DB_USER')
DB_PASSWORD = os.getenv('DB_PASSWORD')

engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')

articles_df.to_sql('articles', con=engine, if_exists='replace', index=False)
# Out:
# 62
